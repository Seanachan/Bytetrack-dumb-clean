# %%
# !nvidia-smi
# Out:
# Tue Nov 25 17:28:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.07                 Driver Version: 566.07         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8             12W /  130W |    5562MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      8004      C   ...\conda\envs\bytetrackllm\python.exe      N/A      |
# |    0   N/A  N/A     17520      C   ...ta\Local\Programs\Ollama\ollama.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
KITTI_PATH = f"{HOME}/refer-kitti/KITTI/training/image_02/"
print(HOME)
# Out:
# D:\CSProject\ByteTrackLLM_HOTA

# %% [markdown]
# # Download Data

# %%
# !gdown -O "0005.zip" "https://drive.google.com/uc?id=1aJx81SILqLSjLzyLUUcLntDxWl2JDSSW"

# %%
# !unzip "/content/0005.zip"
# Out:
# 'unzip' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %% [markdown]
# # Use Ultralytics

# %%
! pip install -U ultralytics
! pip install utils
# Out:
# Requirement already satisfied: ultralytics in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (8.3.231)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (2.2.2+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (0.17.2+cu118)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (1.8.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: utils in c:\users\eason\conda\envs\bytetrackllm\lib\site-packages (1.0.2)

# %%
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))

# %%
# Load a model
model = YOLO("yolo11n.pt")  # load an official model
# model = YOLO("path/to/best.pt")  # load a custom model
print(KITTI_PATH)
# Predict with the model
# results = model("/content/0006/000000.png")  # predict on an image
results = model(r"D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\testing\image_02\0005\000001.png")
  # predict on an image on local disk

# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box

    img = result.plot()
    plt.imshow(img[..., ::-1])
    plt.axis('off')
    print(xyxy)
# Out:
# D:\CSProject\ByteTrackLLM_HOTA/refer-kitti/KITTI/training/image_02/
#
# image 1/1 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\testing\image_02\0005\000001.png: 224x640 2 cars, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 640)
# tensor([[230.6004, 195.3319, 276.7632, 216.5249],
#         [231.4475, 196.2470, 337.2482, 226.5918]], device='cuda:0')

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8

# %%
from __future__ import annotations
from dataclasses import dataclass, field
from typing import Tuple, Optional, List, Dict, Any

import cv2

import numpy as np
# geometry utilities


@dataclass(frozen=True)
class Point:
    x: float
    y: float

    @property
    def int_xy_tuple(self) -> Tuple[int, int]:
        return int(self.x), int(self.y)

@dataclass(frozen=True)
class Rect:
    x: float
    y: float
    width: float
    height: float

    @property
    def min_x(self) -> float:
        return self.x

    @property
    def min_y(self) -> float:
        return self.y

    @property
    def max_x(self) -> float:
        return self.x + self.width

    @property
    def max_y(self) -> float:
        return self.y + self.height

    @property
    def top_left(self) -> Point:
        return Point(x=self.x, y=self.y)

    @property
    def bottom_right(self) -> Point:
        return Point(x=self.x + self.width, y=self.y + self.height)

    @property
    def bottom_center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y + self.height)

    @property
    def top_center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y)

    @property
    def center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y + self.height / 2)

    def pad(self, padding: float) -> Rect:
        return Rect(
            x=self.x - padding,
            y=self.y - padding,
            width=self.width + 2*padding,
            height=self.height + 2*padding
        )

    def contains_point(self, point: Point) -> bool:
        return self.min_x < point.x < self.max_x and self.min_y < point.y < self.max_y


@dataclass
class Detection:
    rect: Rect
    class_id: int
    class_name: str
    confidence: float
    tracker_id: Optional[int] = None

    @classmethod
    def from_results(cls, pred: np.ndarray, names: Dict[int, str]) -> List[Detection]:
        result = []
        for x_min, y_min, x_max, y_max, confidence, class_id in pred:
            class_id=int(class_id)
            result.append(Detection(
                rect=Rect(
                    x=float(x_min),
                    y=float(y_min),
                    width=float(x_max - x_min),
                    height=float(y_max - y_min)
                ),
                class_id=class_id,
                class_name=names[class_id],
                confidence=float(confidence)
            ))
        return result

# %% [markdown]
# # Full video tracking

# %%
from typing import List
import numpy as np
def detections2boxes(detections: List[Detection], with_confidence: bool = True) -> np.ndarray:
    return np.array([
        [
            detection.rect.top_left.x,
            detection.rect.top_left.y,
            detection.rect.bottom_right.x,
            detection.rect.bottom_right.y,
            detection.confidence
        ] if with_confidence else [
            detection.rect.top_left.x,
            detection.rect.top_left.y,
            detection.rect.bottom_right.x,
            detection.rect.bottom_right.y
        ]
        for detection
        in detections
    ], dtype=float)


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: List[Detection],
    tracks: List[STrack]
) -> List[Detection]:
    detection_boxes = detections2boxes(detections=detections, with_confidence=False)
    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detection_boxes)
    track2detection = np.argmax(iou, axis=1)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            detections[detection_index].tracker_id = tracks[tracker_index].track_id
    return detections

# %%
from tqdm.notebook import tqdm

# %%
import os
from ultralytics import YOLO

KITTI_PATH = r"D:\CSProject\ByteTrackLLM_HOTA\refer-kitti"

model = YOLO("yolo11n.pt")
seq = os.path.join(KITTI_PATH, "training", "image_02", "0005")

print("Using path:", seq)
assert os.path.exists(seq), "Path not found!"

results = model.track(source=seq, tracker="bytetrack.yaml", persist=True)
# Out:
# Using path: D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005
#
# image 1/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000000.png: 224x640 3 cars, 18.0ms
# image 2/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000001.png: 224x640 3 cars, 17.3ms
# image 3/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000002.png: 224x640 2 cars, 17.2ms
# image 4/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000003.png: 224x640 2 cars, 17.1ms
# image 5/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000004.png: 224x640 3 cars, 13.8ms
# image 6/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000005.png: 224x640 3 cars, 13.6ms
# image 7/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000006.png: 224x640 3 cars, 13.7ms
# image 8/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000007.png: 224x640 3 cars, 13.6ms
# image 9/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000008.png: 224x640 3 cars, 13.6ms
# image 10/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000009.png: 224x640 3 cars, 12.6ms
# image 11/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000010.png: 224x640 4 cars, 12.5ms
# image 12/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000011.png: 224x640 3 cars, 12.5ms
# image 13/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000012.png: 224x640 3 cars, 12.6ms
# image 14/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000013.png: 224x640 3 cars, 12.4ms
# image 15/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000014.png: 224x640 2 cars, 12.5ms
# image 16/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000015.png: 224x640 2 cars, 10.9ms
# image 17/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000016.png: 224x640 2 cars, 10.9ms
# image 18/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000017.png: 224x640 3 cars, 10.8ms
# image 19/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000018.png: 224x640 3 cars, 10.8ms
# image 20/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000019.png: 224x640 2 cars, 10.9ms
# image 21/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000020.png: 224x640 1 car, 10.9ms
# image 22/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000021.png: 224x640 1 car, 11.2ms
# image 23/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000022.png: 224x640 3 cars, 11.4ms
# image 24/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\
297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000295.png: 224x640 1 car, 10.8ms
# image 297/297 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0005\000296.png: 224x640 1 car, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 7.3ms postprocess per image at shape (1, 3, 224, 640)

# %%
if results:
    # Access the Results object for the first frame
    first_frame_results = results[0]

    # Check if there are any detected boxes in the first frame
    if first_frame_results.boxes is not None:
        print("Detections and Tracks for the First Frame:")
        for box in first_frame_results.boxes:
            # Bounding box coordinates (xyxy format)
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
            print("id: ",box.id[0])

            # Class ID and Name
            class_id = int(box.cls[0].cpu().numpy())
            class_name = first_frame_results.names[class_id]

            # Confidence Score
            confidence = float(box.conf[0].cpu().numpy())

            # Tracker ID (important for tracking results)
            tracker_id = int(box.id[0].cpu().numpy()) if box.id is not None else "N/A"

            print(f"  Object ID: {tracker_id}, Class: {class_name} (ID: {class_id}), Confidence: {confidence:.2f}, BBox: [{x1}, {y1}, {x2}, {y2}]")
    else:
        print("No detections in the first frame.")
else:
    print("No results found. Ensure model.track() was executed successfully.")
# Out:
# Detections and Tracks for the First Frame:
# id:  tensor(1.)
#   Object ID: 1, Class: car (ID: 2), Confidence: 0.63, BBox: [254, 175, 302, 201]
# id:  tensor(2.)
#   Object ID: 2, Class: car (ID: 2), Confidence: 0.54, BBox: [569, 171, 609, 207]
# id:  tensor(3.)
#   Object ID: 3, Class: car (ID: 2), Confidence: 0.37, BBox: [321, 178, 351, 196]

# %%
import json

# helper function to crop the detected objects from the frame
def write_gt(gt_path, save_path, expression_path, labels_path, video_id, expression):
  save_format = "{frame},{id},{x1},{y1},{w},{h},1, 1, 1\n"

  with open(os.path.join(expression_path, video_id, expression+".json")) as f:
      json_info = json.load(f)

  # FIX: Get image dimensions from the first available frame
#   ORI_PATH = f"{HOME}/refer-kitti/training/image_02/{video_id}"
  ORI_PATH = os.path.join(HOME, "refer-kitti", "training", "image_02", video_id)
  # "D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0000"
  first_frame_id = int(list(json_info["label"].keys())[0])
  img_path = os.path.join(ORI_PATH, f"{first_frame_id:06d}.png")
  img = cv2.imread(img_path)
  seq_h, seq_w, _ = img.shape

  labels_path = os.path.join(labels_path, video_id)
  if(not os.path.exists(os.path.join(save_path,video_id,expression)) ):
    os.mkdir(os.path.join(save_path,video_id,expression))
#   print(f"json_info:{json_info}")
  with open(os.path.join(save_path, video_id, expression, "gt.txt"), "w") as f:
      for k in json_info["label"].keys():
          frame_id = int(k)
          if not os.path.isfile(
              os.path.join(labels_path, "{:06d}.txt".format(frame_id))
          ):
              continue
          frame_gt = np.loadtxt(
              os.path.join(labels_path, "{:06d}.txt".format(frame_id))
          ).reshape(-1, 6)
          for frame_gt_line in frame_gt:
              aa = json_info["label"][k]  # all gt from frame
              aa = [int(a) for a in aa]
              if int(frame_gt_line[1]) in aa:  # choose referent gt from all gt
                  track_id = int(frame_gt_line[1])
                  x1, y1, w, h = frame_gt_line[2:6]  # KITTI -> [x1, y1, w, h]
                  line = save_format.format(
                      frame=frame_id + 1,
                      id=track_id,
                      x1=x1 * seq_w,
                      y1=y1 * seq_h,
                      w=w * seq_w,
                      h=h * seq_h,
                  )
                  f.write(line)

#   print("save gt to {}".format(os.path.join(save_path, video_id, expression, "gt.txt")))

# %%
def save_crops_from_detections(box, frame_id, crops_dir):
  """Save cropped images of detected objects for LLM analysis."""
  # ORI_PATH = f"{HOME}/refer-kitti/KITTI/training/image_02/0005"
  ORI_PATH = os.path.join(HOME, "refer-kitti", "training", "image_02", video_id)
  img_path = os.path.join(ORI_PATH, f"{frame_id-1:06d}.png")
  img = cv2.imread(img_path)
  
  seq_h, seq_w, _ = img.shape

  os.makedirs(crops_dir, exist_ok=True)
  x1, y1, x2, y2 = list(map(int, box.xyxy[0]))
  crop = img[y1:y2, x1:x2]
  if crop.size > 0:  # Make sure crop is valid
      save_path = os.path.join(crops_dir, f"i{int(box.id[0])}_f{frame_id}.jpg")
      cv2.imwrite(save_path, crop)

# %%
from dataclasses import dataclass

@dataclass
class Crop_Img:
    frame_id: int
    tracker_id: int
    bbox: dict  # {'x1': ..., 'y1': ..., 'x2': ..., 'y2': ...}
    width: int
    height: int
    crop_path: str
    cls: int = None   # ← optional: new class id

    # ---- properties ----
    @property
    def x1(self):
        return self.bbox.get('x1', 0)
    
    @property
    def y1(self):
        return self.bbox.get('y1', 0)
    
    @property
    def x2(self):
        return self.bbox.get('x2', 0)
    
    @property
    def y2(self):
        return self.bbox.get('y2', 0)

    # ---- class name mapping ----
    def get_class(self, cls_id):
        """Convert class id into readable text."""
        mapping = {
            0: "car",
            1: "pedestrian",
            2: "cyclist",
            3: "truck",
            4: "bus",
            5: "motorcycle",
            6: "bicycle",
        }
        return mapping.get(cls_id, f"class_{cls_id}")

# %%
import os, json, cv2
import shutil
import sys
# add the directory of LLM.py into system path
sys.path.append(r"D:\CSProject\ByteTrackLLM_HOTA\Bytetrack-dumb-clean")
from LLM import select_targets

def inference(EXP_PATH, EXPRESSION_PATH, seq, results):
    SEQ_PATH = os.path.join(EXPRESSION_PATH, seq[0], seq[1])
    save_format = "{frame},{id},{x1},{y1},{w},{h},1,1,1\n"
    with open(SEQ_PATH, "r", encoding="utf-8") as f:
        prompt = json.load(f)
        sentence = prompt.get("sentence", "")

    expression_str = seq[1].split(".")[0]
    exp_dir = os.path.join(EXP_PATH, seq[0], expression_str)
    os.makedirs(exp_dir, exist_ok=True)
    predict_path = os.path.join(exp_dir, "predict.txt")

    os.makedirs("crops/", exist_ok=True)

    first_frame_path = os.path.join(KITTI_PATH, seq[0], f"{1:06d}.png")
    img = cv2.imread(first_frame_path)
    seq_h, seq_w = img.shape[:2]
    existing_ids = set()  # To keep track of existing tracker IDs
    with open(predict_path, "w") as fout:
      for frame_idx, result in enumerate(results, start=1):
        # save crops for this frame
        crop_imgs = []
        for box in result.boxes:
          save_crops_from_detections(box, frame_idx, "crops/")
          # print(list(map(int, box.xyxy[0])))
          # Record bounding box position
          x1, y1, x2, y2 = list(map(float, box.xyxy[0]))
          tracker_id = int(box.id[0]) if box.id is not None else -1

          # Create Crop_Img object using the defined class
          crop_img_obj = Crop_Img(
            frame_id=frame_idx,
            tracker_id=tracker_id,
            bbox={"x1": x1, "y1": y1, "x2": x2, "y2": y2},
            width=x2 - x1,
            height=y2 - y1,
            crop_path=os.path.join(
              "crops/", f"i{tracker_id}_f{frame_idx}.jpg"
            ),
          )
          crop_imgs.append(crop_img_obj)

        # Call select_targets once every 30 frames
        if (frame_idx-1) % 30 == 0 and crop_imgs:
          matches = select_targets(
            crops_dir="crops/",
            prompt=sentence,
            # device="cuda:0",
            quiet=False,
            img_size={"img_h": seq_h, "img_w": seq_w},
            crop_info=crop_imgs,  # Pass list of Crop_Img objects
          )
          existing_ids.update(match for match in matches)  # Update existing IDs
        else:
          matches = existing_ids  # Keep track of existing IDs

        # Write predictions for matched objects with actual bounding boxes
        for crop_img in crop_imgs:
          if crop_img.tracker_id in matches:
            x1 = crop_img.bbox['x1']
            y1 = crop_img.bbox['y1']
            w = crop_img.width
            h = crop_img.height
            
            line = save_format.format(
              frame=frame_idx,
              id=crop_img.tracker_id,
              x1=x1,
              y1=y1,
              w=w,
              h=h
            )
            print(f"Frame {frame_idx}, ID {crop_img.tracker_id}: x1={x1}, y1={y1}, w={w}, h={h}")
            fout.write(line)
          
        # Clean up crops directory
        if os.path.exists("crops/"):
          shutil.rmtree("crops/")
        os.makedirs("crops/", exist_ok=True)

# %%
import importlib
import LLM
importlib.reload(LLM)
from LLM import select_targets

# %%
import os
import numpy as np
from ultralytics import YOLO # import YOLO
model = YOLO("yolo11n.pt") # initial model

# 1. path set
HOME = r"D:\CSProject\ByteTrackLLM_HOTA"
os.chdir(HOME)
print("HOME =", HOME)

KITTI_PATH = os.path.join(HOME, "refer-kitti", "training", "image_02")
# "D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02"
print("KITTI_PATH =", KITTI_PATH)

result_num = 1

# 2. path of folders
EXPRESSION_PATH = os.path.join(HOME, "refer-kitti", "expression")
# "D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\expression"
GT_PATH = os.path.join(HOME, "labels_with_ids","image_02")
# "D:\CSProject\ByteTrackLLM_HOTA\labels_with_ids\image_02"

EXP_PATH = os.path.join(HOME, "exps", f"results_{result_num}")
LABELS_PATH = GT_PATH  

# ensure output folder exist
os.makedirs(EXP_PATH, exist_ok=True)

EXP_NUM = "0005"
images_dir = os.path.join(KITTI_PATH, EXP_NUM)
sequence_id = os.path.basename(images_dir.rstrip("/"))
expression_dir = os.path.join(EXPRESSION_PATH, EXP_NUM)
sentence = ""

if "refer-kitti-v2" in EXPRESSION_PATH:
    video_ids = ["0005", "0011", "0013", "0019"]
else:
    video_ids = ["0005", "0011", "0013"]

print("video_ids =", video_ids)

for video_id in video_ids[1:]:
    video_path = os.path.join(KITTI_PATH, video_id)
    print(f"Running YOLO tracking for {video_id}...")
    current_results = model.track(source=video_path, tracker="bytetrack.yaml", persist=True)
    expr_dir = os.path.join(EXPRESSION_PATH, video_id)
    print(f"\nProcessing video_id = {video_id}")
    print("Expression dir =", expr_dir)

    # list all expression json files of this video 
    expression_jsons = sorted(os.listdir(expr_dir))

    # consist [[video_id, expression_json], ...]
    seq_nums = [[video_id, expression_json] for expression_json in expression_jsons]

    # run write_gt + inference per expression 
    for seq_num in seq_nums:
        vid = seq_num[0]
        expr_file = seq_num[1]
        expr_stem = expr_file.split(".")[0]

        # make sure (video, expression) output folder exist
        out_dir = os.path.join(EXP_PATH, vid, expr_stem)
        os.makedirs(out_dir, exist_ok=True)

        print(f"  -> expression: {vid}/{expr_file}")

        write_gt(
            GT_PATH,
            EXP_PATH,
            EXPRESSION_PATH,
            LABELS_PATH,
            vid,
            expr_stem,
        )

        # use `results` from last cell (YOLO)
        inference(
            EXP_PATH,
            EXPRESSION_PATH,
            seq_num,
            current_results,
        )
# Out:
# HOME = D:\CSProject\ByteTrackLLM_HOTA
# KITTI_PATH = D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02
# video_ids = ['0005', '0011', '0013']
# Running YOLO tracking for 0011...
#
# image 1/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000000.png: 224x640 7 cars, 18.4ms
# image 2/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000001.png: 224x640 6 cars, 17.2ms
# image 3/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000002.png: 224x640 6 cars, 17.2ms
# image 4/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000003.png: 224x640 6 cars, 17.6ms
# image 5/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000004.png: 224x640 6 cars, 17.2ms
# image 6/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000005.png: 224x640 6 cars, 13.9ms
# image 7/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000006.png: 224x640 6 cars, 13.9ms
# image 8/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000007.png: 224x640 5 cars, 13.8ms
# image 9/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000008.png: 224x640 5 cars, 13.9ms
# image 10/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000009.png: 224x640 5 cars, 13.9ms
# image 11/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000010.png: 224x640 4 cars, 12.7ms
# image 12/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000011.png: 224x640 5 cars, 12.7ms
# image 13/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000012.png: 224x640 6 cars, 12.6ms
# image 14/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000013.png: 224x640 1 person, 6 cars, 12.6ms
# image 15/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000014.png: 224x640 6 cars, 12.5ms
# image 16/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000015.png: 224x640 6 cars, 12.5ms
# image 17/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000016.png: 224x640 5 cars, 11.3ms
# image 18/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000017.png: 224x640 5 cars, 10.8ms
# image 19/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000018.png: 224x640 5 cars, 11.5ms
# image 20/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000019.png: 224x640 1 person, 5 cars, 11.4ms
# image 21/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000020.png: 224x640 1 person, 5 cars, 11.7ms
# image 22/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000021.png: 224x640 1 person, 4 cars, 11.0ms
# image 23/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000022.png: 224x640 1 person, 4 cars, 11.5ms
# image 24/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000023.png: 224x640 1 person, 4 cars, 11.6ms
# image 25/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000024.png: 224x640 1 person, 4 cars, 11.6ms
# image 26/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000025.png: 224x640 1 person, 4 cars, 12.4ms
# image 27/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000026.png: 224x640 1 person, 3 cars, 11.8ms
# image 28/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000027.png: 224x640 1 person, 2 cars, 11.2ms
# image 29/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000028.png: 224x640 1 person, 2 cars, 11.0ms
# image 30/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000029.png: 224x640 1 person, 2 cars, 11.0ms
# image 31/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000030.png: 224x640 1 person, 2 cars, 11.4ms
# image 32/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000031.png: 224x640 1 person, 2 cars, 13.9ms
# image 33/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000032.png: 224x640 1 person, 2 cars, 14.8ms
# image 34/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000033.png: 224x640 1 person, 3 cars, 12.4ms
# image 35/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000034.png: 224x640 1 person, 2 cars, 10.9ms
# image 36/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000035.png: 224x640 1 person, 2 cars, 11.2ms
# image 37/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000036.png: 224x640 1 person, 1 car, 11.0ms
# image 38/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000037.png: 224x640 1 person, 1 car, 11.1ms
# image 39/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000038.png: 224x640 1 person, 1 car, 11.6ms
# image 40/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000039.png: 224x640 1 person, 2 cars, 10.5ms
# image 41/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\
373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000195.png: 224x640 1 person, 9 cars, 11.9ms
# image 197/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000196.png: 224x640 7 cars, 10.6ms
# image 198/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000197.png: 224x640 7 cars, 10.5ms
# image 199/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000198.png: 224x640 7 cars, 11.5ms
# image 200/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000199.png: 224x640 1 person, 6 cars, 13.5ms
# image 201/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000200.png: 224x640 1 person, 7 cars, 11.0ms
# image 202/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000201.png: 224x640 1 person, 7 cars, 10.9ms
# image 203/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000202.png: 224x640 1 person, 6 cars, 10.6ms
# image 204/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000203.png: 224x640 1 person, 7 cars, 11.3ms
# image 205/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000204.png: 224x640 1 person, 7 cars, 10.9ms
# image 206/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000205.png: 224x640 1 person, 7 cars, 10.5ms
# image 207/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000206.png: 224x640 1 person, 7 cars, 11.7ms
# image 208/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000207.png: 224x640 1 person, 8 cars, 11.2ms
# image 209/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000208.png: 224x640 1 person, 9 cars, 11.2ms
# image 210/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000209.png: 224x640 1 person, 9 cars, 11.1ms
# image 211/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000210.png: 224x640 1 person, 9 cars, 10.7ms
# image 212/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000211.png: 224x640 1 person, 8 cars, 11.0ms
# image 213/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000212.png: 224x640 1 person, 8 cars, 1 fire hydrant, 10.8ms
# image 214/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000213.png: 224x640 1 person, 8 cars, 10.7ms
# image 215/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000214.png: 224x640 1 person, 9 cars, 11.2ms
# image 216/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000215.png: 224x640 8 cars, 1 fire hydrant, 11.1ms
# image 217/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000216.png: 224x640 1 person, 8 cars, 10.9ms
# image 218/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000217.png: 224x640 1 person, 10 cars, 11.0ms
# image 219/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000218.png: 224x640 1 person, 11 cars, 11.2ms
# image 220/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000219.png: 224x640 1 person, 10 cars, 10.9ms
# image 221/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000220.png: 224x640 1 person, 11 cars, 11.1ms
# image 222/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000221.png: 224x640 1 person, 11 cars, 10.6ms
# image 223/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000222.png: 224x640 1 person, 10 cars, 10.9ms
# image 224/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000223.png: 224x640 10 cars, 1 fire hydrant, 11.1ms
# image 225/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000224.png: 224x640 11 cars, 1 fire hydrant, 10.7ms
# image 226/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000225.png: 224x640 11 cars, 1 fire hydrant, 11.3ms
# image 227/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000226.png: 224x640 1 person, 11 cars, 1 fire hydrant, 10.8ms
# image 228/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000227.png: 224x640 1 person, 10 cars, 11.2ms
# image 229/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000228.png: 224x640 1 person, 10 cars, 1 fire hydrant, 10.8ms
# image 230/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000229.png: 224x640 1 person, 10 cars, 1 fire hydrant, 11.1ms
# image 231/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000230.png: 224x640 1 person, 10 cars, 1 fire hydrant, 10.6ms
# image 232/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000231.png: 224x640 1 person, 10 cars, 1 fire hydrant, 10.9ms
# image 233/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000232.png: 224x640 1 person, 10 cars, 1 fire hydrant, 10.8ms
# image 234/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000233.png: 224x640 1 person, 11 cars, 1 fire hydrant, 11.1ms
# image 235/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000234.png: 224x640 1 person, 13 cars, 1 fire hydrant, 11.1ms
# image 236/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000235.png: 224x640 1 person, 13 cars, 1 fire hydrant, 11.2ms
# image 237/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000236.png: 224x640 1 person, 12 cars, 1 fire hydrant, 10.8ms
# image 238/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000237.png: 224x640 1 person, 13 cars, 1 fire hydrant, 10.8ms
# image 239/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\
373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000341.png: 224x640 2 cars, 10.9ms
# image 343/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000342.png: 224x640 2 cars, 11.1ms
# image 344/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000343.png: 224x640 2 cars, 10.7ms
# image 345/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000344.png: 224x640 2 cars, 10.8ms
# image 346/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000345.png: 224x640 2 cars, 11.1ms
# image 347/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000346.png: 224x640 2 cars, 10.5ms
# image 348/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000347.png: 224x640 2 cars, 10.7ms
# image 349/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000348.png: 224x640 2 cars, 11.3ms
# image 350/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000349.png: 224x640 2 cars, 10.9ms
# image 351/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000350.png: 224x640 2 cars, 10.8ms
# image 352/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000351.png: 224x640 2 cars, 11.1ms
# image 353/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000352.png: 224x640 2 cars, 10.7ms
# image 354/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000353.png: 224x640 2 cars, 10.6ms
# image 355/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000354.png: 224x640 2 cars, 10.9ms
# image 356/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000355.png: 224x640 2 cars, 11.3ms
# image 357/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000356.png: 224x640 1 car, 10.7ms
# image 358/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000357.png: 224x640 1 car, 10.6ms
# image 359/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000358.png: 224x640 1 car, 11.4ms
# image 360/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000359.png: 224x640 1 car, 10.8ms
# image 361/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000360.png: 224x640 1 car, 10.4ms
# image 362/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000361.png: 224x640 1 car, 11.1ms
# image 363/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000362.png: 224x640 1 car, 11.0ms
# image 364/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000363.png: 224x640 1 car, 10.6ms
# image 365/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000364.png: 224x640 1 car, 10.5ms
# image 366/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000365.png: 224x640 1 car, 10.9ms
# image 367/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000366.png: 224x640 1 car, 11.0ms
# image 368/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000367.png: 224x640 1 car, 11.0ms
# image 369/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000368.png: 224x640 1 car, 10.9ms
# image 370/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000369.png: 224x640 1 car, 12.0ms
# image 371/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000370.png: 224x640 1 car, 11.1ms
# image 372/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000371.png: 224x640 1 car, 10.7ms
# image 373/373 D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\training\image_02\0011\000372.png: 224x640 1 car, 10.7ms
# Speed: 1.6ms preprocess, 11.3ms inference, 11.2ms postprocess per image at shape (1, 3, 224, 640)
#
# Processing video_id = 0011
# Expression dir = D:\CSProject\ByteTrackLLM_HOTA\refer-kitti\expression\0011
#   -> expression: 0011/black-cars-in-right.json
# [INFO] (1/11) Processing i1_f1.jpg
# [Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 15.622306823730469, 'y1': 175.79769897460938, 'x2': 215.95223999023438, 'y2': 261.390869140625}, width=200.3299331665039, height=85.59317016601562, crop_path='crops/i1_f1.jpg', cls=None), Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 1103.80029296875, 'y1': 209.21893310546875, 'x2': 1241.6883544921875, 'y2': 366.8800048828125}, width=137.8880615234375, height=157.66107177734375, crop_path='crops/i2_f1.jpg', cls=None), Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 561.234130859375, 'y1': 174.62774658203125, 'x2': 652.369384765625, 'y2': 256.7405090332031}, width=91.13525390625, height=82.11276245117188, crop_path='crops/i3_f1.jpg', cls=None), Crop_Img(frame_id=1, tracker_id=4, bbox={'x1': 884.22802734375, 'y1': 171.42526245117188, 'x2': 1133.656494140625, 'y2': 333.81298828125}, width=249.428466796875, height=162.38772583007812, crop_path='crops/i4_f1.jpg', cls=None), Crop_Img(frame_id=1, tracker_id=5, b
f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=471, bbox={'x1': 419.15985107421875, 'y1': 179.43234252929688, 'x2': 466.18011474609375, 'y2': 204.60780334472656}, width=47.020263671875, height=25.175460815429688, crop_path='crops/i471_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=475, bbox={'x1': 669.1464233398438, 'y1': 176.51226806640625, 'x2': 707.3704223632812, 'y2': 207.9076385498047}, width=38.2239990234375, height=31.395370483398438, crop_path='crops/i475_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=492, bbox={'x1': 317.2694396972656, 'y1': 181.88427734375, 'x2': 378.1324157714844, 'y2': 225.47254943847656}, width=60.86297607421875, height=43.58827209472656, crop_path='crops/i492_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=335, bbox={'x1': 775.7869262695312, 'y1': 172.50193786621094, 'x2': 819.808349609375, 'y2': 240.71971130371094}, width=44.02142333984375, height=68.2177734375, crop_path='crops/i335_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=441, bbox={'x1': 211.16436767578125, 'y1': 179.67874145507812, 'x2': 293.113525390625, 'y2': 239.79595947265625}, width=81.94915771484375, height=60.117218017578125, crop_path='crops/i441_f181.jpg', cls=None)]
# [DEBUG] LLM response: no
# [INFO] (4/8) Processing i441_f181.jpg
# [Crop_Img(frame_id=181, tracker_id=3, bbox={'x1': 585.6973266601562, 'y1': 176.04583740234375, 'x2': 667.894775390625, 'y2': 248.5777130126953}, width=82.19744873046875, height=72.53187561035156, crop_path='crops/i3_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=439, bbox={'x1': 733.9796752929688, 'y1': 174.54127502441406, 'x2': 802.8319091796875, 'y2': 242.92991638183594}, width=68.85223388671875, height=68.38864135742188, crop_path='crops/i439_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=454, bbox={'x1': 0.0, 'y1': 55.050201416015625, 'x2': 270.1937255859375, 'y2': 331.2344665527344}, width=270.1937255859375, height=276.18426513671875, crop_path='crops/i454_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=471, bbox={'x1': 419.15985107421875, 'y1': 179.43234252929688, 'x2': 466.18011474609375, 'y2': 204.60780334472656}, width=47.020263671875, height=25.175460815429688, crop_path='crops/i471_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=475, bbox={'x1': 669.1464233398438, 'y1': 176.51226806640625, 'x2': 707.3704223632812, 'y2': 207.9076385498047}, width=38.2239990234375, height=31.395370483398438, crop_path='crops/i475_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=492, bbox={'x1': 317.2694396972656, 'y1': 181.88427734375, 'x2': 378.1324157714844, 'y2': 225.47254943847656}, width=60.86297607421875, height=43.58827209472656, crop_path='crops/i492_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=335, bbox={'x1': 775.7869262695312, 'y1': 172.50193786621094, 'x2': 819.808349609375, 'y2': 240.71971130371094}, width=44.02142333984375, height=68.2177734375, crop_path='crops/i335_f181.jpg', cls=None), Crop_Img(frame_id=181, tracker_id=441, bbox={'x1': 211.16436767578125, 'y1': 179.67874145507812, 'x2': 293.113525390625, 'y2': 239.79595947265625}, width=81.94915771484375, height=60.117218017578125, crop_path='crops/i441_f181.jpg', cls=None)]
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 無法連線，因為目標電腦拒絕連線。
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 87
#      77 write_gt(
#      78     GT_PATH,
#      79     EXP_PATH,
#    (...)
#      83     expr_stem,
#      84 )
#      86 # 這裡用外面的 `results`（你自己上一個 cell 跑 YOLO 得到的）
# ---> 87 inference(
#      88     EXP_PATH,
#      89     EXPRESSION_PATH,
#      90     seq_num,
#      91     current_results,
#      92 )
#
# Cell In[32], line 52, in inference(EXP_PATH, EXPRESSION_PATH, seq, results)
#      50 # Call select_targets once every 30 frames
#      51 if (frame_idx-1) % 30 == 0 and crop_imgs:
# ---> 52   matches = select_targets(
#      53     crops_dir="crops/",
#      54     prompt=sentence,
#      55     # device="cuda:0",
#      56     quiet=False,
#      57     img_size={"img_h": seq_h, "img_w": seq_w},
#      58     crop_info=crop_imgs,  # Pass list of Crop_Img objects
#      59   )
#      60   existing_ids.update(match for match in matches)  # Update existing IDs
#      61 else:
#
# File D:\CSProject\ByteTrackLLM_HOTA\Bytetrack-dumb-clean\LLM.py:155, in select_targets(crops_dir, prompt, quiet, img_size, crop_info)
#     135 payload = {
#     136     "model": "qwen2.5vl",
#     137     "prompt": (
#    (...)
#     151     "images": [encode_image(f)],
#     152 }
#     154 try:
# --> 155     resp = requests.post(API_URL, json=payload, stream=True)
#     156     resp.raise_for_status()
#     157 except Exception as e:
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#     509 except BrokenPipeError:
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     439 for header, value in headers.items():
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#     444 if chunks is not None:
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1249 else:
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1009 msg = b"\r\n".join(self._buffer)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#    1016     if hasattr(message_body, 'read'):
#    1017         # Let file-like take precedence over byte-like.  This
#    1018         # is needed to allow the current position of mmap'ed
#    1019         # files to be taken into account.
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     949 if self.sock is None:
#     950     if self.auto_open:
# --> 951         self.connect()
#     952     else:
#     953         raise NotConnected()
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#     282         self._has_connected_to_proxy = True
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\Eason\conda\envs\bytetrackllm\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create output directory
#
# ### Subtask:
# Create a directory to store the annotated frames and the final video.

# %% [markdown]
# **Reasoning**:
# To create the output directory as instructed, I will import the `os` module, define the directory name, and then use `os.makedirs` to create it.

# %%
import os

output_dir = os.path.join(HOME, "tracking_output")
os.makedirs(output_dir, exist_ok=True)
print(f"Output directory created at: {output_dir}")

# %% [markdown]
# **Reasoning**:
# Now that the output directory is created, I need to iterate through the `results` object obtained from `model.track()`, save each annotated frame as an image file in the newly created `output_dir`.

# %%
for i, result in enumerate(results):
    # Save the annotated image to the output directory
    image_path = os.path.join(output_dir, f"frame_{i:04d}.jpg") # Using JPG for smaller size
    result.save(filename=image_path)
    if i % 50 == 0:
        print(f"Saved frame {i} to {image_path}")
print(f"All annotated frames saved to {output_dir}")

# %% [markdown]
# **Reasoning**:
# Now that all annotated frames are saved, I will use OpenCV to compile these frames into a video file. I'll define video parameters like codec, frame rate, and output path, then iterate through the saved images, read them, and write them to the video.

# %%
import cv2
import glob

# Get a list of all saved image files, sorted by name to ensure correct frame order
image_files = sorted(glob.glob(os.path.join(output_dir, "frame_*.jpg")))

if not image_files:
    print("No frames found to create video.")
else:
    # Read the first image to get dimensions
    first_frame = cv2.imread(image_files[0])
    height, width, layers = first_frame.shape
    size = (width, height)

    # Define the codec and create VideoWriter object
    video_name = os.path.join(output_dir, 'tracking_output.mp4')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # You can choose other codecs like 'MJPG', 'XVID', 'mp4v'
    fps = 10 # Frames per second
    out = cv2.VideoWriter(video_name, fourcc, fps, size)

    # Write each frame to the video file
    for img_file in image_files:
        img = cv2.imread(img_file)
        out.write(img)

    out.release()
    print(f"Video created successfully at: {video_name}")

# %%
# Run draw_boxes.py from the notebook cell
import os, subprocess, shlex

images_dir = os.path.join(KITTI_PATH, "0005")
cmd = f'python draw_boxes.py --gt_file predict.txt --images_dir "{images_dir}" --output_dir tracking_viz'

print("Running:", cmd)
proc = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
print(proc.stdout)
if proc.returncode != 0:
    print("Return code:", proc.returncode)
    print(proc.stderr)

# %% [markdown]
# # Looping through all files in refer-kitti
