# %%
# !nvidia-smi
# Out:
# Thu Nov 20 00:45:00 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# |  0%   55C    P2             67W /  225W |    7608MiB /   8192MiB |     14%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2594      G   /usr/lib/xorg/Xorg                      527MiB |
# |    0   N/A  N/A            2822      G   /usr/bin/gnome-shell                    166MiB |
# |    0   N/A  N/A            6405      G   .../7298/usr/lib/firefox/firefox        147MiB |
# |    0   N/A  N/A           30005    C+G   /usr/bin/warp-terminal                   20MiB |
# |    0   N/A  N/A           42707      G   /usr/bin/nautilus                       103MiB |
# |    0   N/A  N/A          442652      G   /usr/share/code/code                    613MiB |
# |    0   N/A  N/A          456852      C   ...nda/envs/ByteTrack/bin/python        546MiB |
# |    0   N/A  N/A          495203      C   /usr/local/bin/ollama                  5352MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
KITTI_PATH = f"{HOME}/refer-kitti/KITTI/training/image_02/"
print(HOME)
# Out:
# /home/seanachan/ByteTrack_ultralytics

# %% [markdown]
# # Download Data

# %%
# !gdown -O "0005.zip" "https://drive.google.com/uc?id=1aJx81SILqLSjLzyLUUcLntDxWl2JDSSW"

# %%
# !unzip "/content/0005.zip"

# %% [markdown]
# # Use Ultralytics

# %%
! pip install -U ultralytics
! pip install utils

# %%
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))

# %%
# Load a model
model = YOLO("yolo11n.pt")  # load an official model
# model = YOLO("path/to/best.pt")  # load a custom model

# Predict with the model
# results = model("/content/0006/000000.png")  # predict on an image
results = model(f"{KITTI_PATH}/0005/000001.png")  # predict on an image on local disk

# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box

    img = result.plot()
    plt.imshow(img[..., ::-1])
    plt.axis('off')
    print(xyxy)
# Out:
# image 1/1 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000001.png: 224x640 4 cars, 77.6ms
# Speed: 0.7ms preprocess, 77.6ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 640)
# tensor([[570.2890, 172.9945, 609.8477, 205.3806],
#         [240.5006, 174.5513, 274.7550, 201.0368],
#         [238.9740, 175.2660, 292.8930, 199.0744],
#         [315.9764, 176.7250, 341.7189, 196.2018]], device='cuda:0')

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8

# %%
from __future__ import annotations
from dataclasses import dataclass, field
from typing import Tuple, Optional, List, Dict, Any

import cv2

import numpy as np
# geometry utilities


@dataclass(frozen=True)
class Point:
    x: float
    y: float

    @property
    def int_xy_tuple(self) -> Tuple[int, int]:
        return int(self.x), int(self.y)

@dataclass(frozen=True)
class Rect:
    x: float
    y: float
    width: float
    height: float

    @property
    def min_x(self) -> float:
        return self.x

    @property
    def min_y(self) -> float:
        return self.y

    @property
    def max_x(self) -> float:
        return self.x + self.width

    @property
    def max_y(self) -> float:
        return self.y + self.height

    @property
    def top_left(self) -> Point:
        return Point(x=self.x, y=self.y)

    @property
    def bottom_right(self) -> Point:
        return Point(x=self.x + self.width, y=self.y + self.height)

    @property
    def bottom_center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y + self.height)

    @property
    def top_center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y)

    @property
    def center(self) -> Point:
        return Point(x=self.x + self.width / 2, y=self.y + self.height / 2)

    def pad(self, padding: float) -> Rect:
        return Rect(
            x=self.x - padding,
            y=self.y - padding,
            width=self.width + 2*padding,
            height=self.height + 2*padding
        )

    def contains_point(self, point: Point) -> bool:
        return self.min_x < point.x < self.max_x and self.min_y < point.y < self.max_y


@dataclass
class Detection:
    rect: Rect
    class_id: int
    class_name: str
    confidence: float
    tracker_id: Optional[int] = None

    @classmethod
    def from_results(cls, pred: np.ndarray, names: Dict[int, str]) -> List[Detection]:
        result = []
        for x_min, y_min, x_max, y_max, confidence, class_id in pred:
            class_id=int(class_id)
            result.append(Detection(
                rect=Rect(
                    x=float(x_min),
                    y=float(y_min),
                    width=float(x_max - x_min),
                    height=float(y_max - y_min)
                ),
                class_id=class_id,
                class_name=names[class_id],
                confidence=float(confidence)
            ))
        return result

# %% [markdown]
# # Full video tracking

# %%
from typing import List
import numpy as np
def detections2boxes(detections: List[Detection], with_confidence: bool = True) -> np.ndarray:
    return np.array([
        [
            detection.rect.top_left.x,
            detection.rect.top_left.y,
            detection.rect.bottom_right.x,
            detection.rect.bottom_right.y,
            detection.confidence
        ] if with_confidence else [
            detection.rect.top_left.x,
            detection.rect.top_left.y,
            detection.rect.bottom_right.x,
            detection.rect.bottom_right.y
        ]
        for detection
        in detections
    ], dtype=float)


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: List[Detection],
    tracks: List[STrack]
) -> List[Detection]:
    detection_boxes = detections2boxes(detections=detections, with_confidence=False)
    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detection_boxes)
    track2detection = np.argmax(iou, axis=1)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            detections[detection_index].tracker_id = tracks[tracker_index].track_id
    return detections

# %%
from tqdm.notebook import tqdm

# %%
model = YOLO("yolo11n.pt")
results = model.track(source=f"{KITTI_PATH}/0005", tracker="bytetrack.yaml",persist=True)
# Out:
# image 1/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000000.png: 224x640 3 cars, 3.6ms
# image 2/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000001.png: 224x640 3 cars, 2.9ms
# image 3/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000002.png: 224x640 2 cars, 3.2ms
# image 4/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000003.png: 224x640 2 cars, 3.0ms
# image 5/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000004.png: 224x640 3 cars, 3.3ms
# image 6/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000005.png: 224x640 3 cars, 3.2ms
# image 7/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000006.png: 224x640 3 cars, 3.0ms
# image 8/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000007.png: 224x640 3 cars, 3.2ms
# image 9/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000008.png: 224x640 3 cars, 3.0ms
# image 10/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000009.png: 224x640 3 cars, 3.0ms
# image 11/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000010.png: 224x640 4 cars, 3.2ms
# image 12/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000011.png: 224x640 3 cars, 3.0ms
# image 13/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000012.png: 224x640 3 cars, 2.9ms
# image 14/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000013.png: 224x640 3 cars, 3.0ms
# image 15/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000014.png: 224x640 2 cars, 3.1ms
# image 16/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000015.png: 224x640 2 cars, 3.2ms
# image 17/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000016.png: 224x640 2 cars, 3.3ms
# image 18/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000017.png: 224x640 3 cars, 3.0ms
# image 19/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000018.png: 224x640 3 cars, 3.8ms
# image 20/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000019.png: 224x640 2 cars, 4.1ms
# image 21/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000020.png: 224x640 1 car, 3.3ms
# image 22/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000021.png: 224x640 1 car, 3.1ms
# image 23/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000022.png: 224x640 3 cars, 3.1ms
# image 24/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000023.png: 224x640 3 cars, 3.4ms
# image 25/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000024.png: 224x640 3 cars, 3.4ms
# image 26/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000025.png: 224x640 3 cars, 3.2ms
# image 27/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000026.png: 224x640 3 cars, 8.4ms
# image 28/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000027.png: 224x640 3 cars, 3.3ms
# image 29/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000028.png: 224x640 3 cars, 3.2ms
# image 30/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000029.png: 224x640 3 cars, 3.2ms
# image 31/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000030.png: 224x640 3 cars, 3.3ms
# image 32/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000031.png: 224x640 3 cars, 3.3ms
# image 33/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000032.png: 224x640 4 cars, 3.1ms
# image 34/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000033.png: 224x640 4 cars, 8.2ms
# image 35/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000034.png: 224x640 4 cars, 3.4ms
# image 36/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000035.png: 224x640 4 cars, 3.1ms
# image 37/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000036.png: 224x640 3 cars, 3.4ms
# image 38/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000037.png: 224x640 3 cars, 3.2ms
# image 39/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000038.png: 224x640 4 cars, 3.2ms
# image 40/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000039.png: 224x640 4 cars, 3.2ms
# image 41/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000040.png: 224x640 5 cars, 3.1ms
# image 42/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000041.png: 224x640 4 cars, 3.1ms
# image 43/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000042.png: 224x640 3 cars, 1 truck, 3.1ms
# image 44/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000043.png: 224x640 3 cars, 3.1ms
# image 45/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000044.png: 224x640 3 cars, 3.0ms
# image 46/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000045.png: 224x640 3 cars, 3.6ms
# image 47/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000046.png: 224x640 2 cars, 1 truck, 3.3ms
# image 48/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000047.png: 224x640 3 cars, 3.4ms
# image 49/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000048.png: 224x640 4 cars, 3.0ms
# image 50/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000049.png: 224x640 4 cars, 3.1ms
# image 51/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000050.png: 224x640 4 cars, 3.1ms
# image 52/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000051.png: 224x640 3 cars, 1 truck, 3.0ms
# image 53/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000052.png: 224x640 4 cars, 3.0ms
# image 54/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000053.png: 224x640 4 cars, 2.9ms
# image 55/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000054.png: 224x640 4 cars, 2.9ms
# image 56/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000055.png: 224x640 4 cars, 3.2ms
# image 57/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000056.png: 224x640 4 cars, 3.1ms
# image 58/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000057.png: 224x640 4 cars, 3.0ms
# image 59/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000058.png: 224x640 3 cars, 3.3ms
# image 60/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000059.png: 224x640 3 cars, 3.0ms
# image 61/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000060.png: 224x640 5 cars, 3.1ms
# image 62/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000061.png: 224x640 4 cars, 3.0ms
# image 63/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000062.png: 224x640 4 cars, 3.0ms
# image 64/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000063.png: 224x640 5 cars, 2.9ms
# image 65/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000064.png: 224x640 4 cars, 3.2ms
# image 66/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000065.png: 224x640 4 cars, 3.0ms
# image 67/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000066.png: 224x640 3 cars, 3.0ms
# image 68/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000067.png: 224x640 3 cars, 3.1ms
# image 69/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000068.png: 224x640 4 cars, 3.0ms
# image 70/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000069.png: 224x640 5 cars, 3.2ms
# image 71/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000070.png: 224x640 5 cars, 3.0ms
# image 72/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000071.png: 224x640 2 cars, 2.9ms
# image 73/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000072.png: 224x640 3 cars, 3.2ms
# image 74/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000073.png: 224x640 2 cars, 3.0ms
# image 75/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000074.png: 224x640 3 cars, 3.1ms
# image 76/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000075.png: 224x640 3 cars, 2.9ms
# image 77/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000076.png: 224x640 2 cars, 3.5ms
# image 78/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000077.png: 224x640 3 cars, 3.1ms
# image 79/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000078.png: 224x640 3 cars, 3.0ms
# image 80/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000079.png: 224x640 3 cars, 3.1ms
# image 81/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000080.png: 224x640 3 cars, 3.7ms
# image 82/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000081.png: 224x640 3 cars, 3.0ms
# image 83/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000082.png: 224x640 3 cars, 3.6ms
# image 84/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000083.png: 224x640 4 cars, 2.9ms
# image 85/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000084.png: 224x640 3 cars, 3.0ms
# image 86/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000085.png: 224x640 2 cars, 3.7ms
# image 87/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000086.png: 224x640 3 cars, 3.3ms
# image 88/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000087.png: 224x640 3 cars, 3.0ms
# image 89/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000088.png: 224x640 5 cars, 3.0ms
# image 90/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000089.png: 224x640 4 cars, 2.9ms
# image 91/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000090.png: 224x640 4 cars, 3.0ms
# image 92/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000091.png: 224x640 4 cars, 2.9ms
# image 93/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000092.png: 224x640 4 cars, 2.9ms
# image 94/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000093.png: 224x640 4 cars, 3.6ms
# image 95/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000094.png: 224x640 3 cars, 2.9ms
# image 96/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000095.png: 224x640 3 cars, 2.9ms
# image 97/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000096.png: 224x640 4 cars, 3.0ms
# image 98/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000097.png: 224x640 4 cars, 2.9ms
# image 99/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000098.png: 224x640 5 cars, 3.0ms
# image 100/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000099.png: 224x640 5 cars, 3.3ms
# image 101/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000100.png: 224x640 3 cars, 2.9ms
# image 102/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000101.png: 224x640 3 cars, 2.9ms
# image 103/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000102.png: 224x640 4 cars, 3.0ms
# image 104/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000103.png: 224x640 3 cars, 3.0ms
# image 105/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000104.png: 224x640 3 cars, 3.3ms
# image 106/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000105.png: 224x640 3 cars, 3.0ms
# image 107/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000106.png: 224x640 3 cars, 3.6ms
# image 108/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000107.png: 224x640 5 cars, 3.0ms
# image 109/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000108.png: 224x640 5 cars, 3.0ms
# image 110/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000109.png: 224x640 3 cars, 3.0ms
# image 111/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000110.png: 224x640 3 cars, 3.0ms
# image 112/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000111.png: 224x640 3 cars, 3.8ms
# image 113/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000112.png: 224x640 3 cars, 3.1ms
# image 114/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000113.png: 224x640 3 cars, 3.0ms
# image 115/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000114.png: 224x640 3 cars, 2.9ms
# image 116/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000115.png: 224x640 2 cars, 3.2ms
# image 117/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000116.png: 224x640 2 cars, 2.9ms
# image 118/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000117.png: 224x640 2 cars, 3.2ms
# image 119/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000118.png: 224x640 2 cars, 2.9ms
# image 120/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000119.png: 224x640 1 car, 3.7ms
# image 121/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000120.png: 224x640 1 car, 2.9ms
# image 122/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000121.png: 224x640 1 car, 3.7ms
# image 123/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000122.png: 224x640 1 car, 3.0ms
# image 124/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000123.png: 224x640 1 car, 3.7ms
# image 125/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000124.png: 224x640 1 car, 3.0ms
# image 126/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000125.png: 224x640 1 car, 3.0ms
# image 127/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000126.png: 224x640 1 car, 3.0ms
# image 128/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000127.png: 224x640 1 car, 3.1ms
# image 129/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000128.png: 224x640 1 car, 3.0ms
# image 130/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000129.png: 224x640 1 car, 3.0ms
# image 131/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000130.png: 224x640 1 car, 3.0ms
# image 132/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000131.png: 224x640 1 car, 3.1ms
# image 133/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000132.png: 224x640 1 car, 3.0ms
# image 134/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000133.png: 224x640 1 car, 3.9ms
# image 135/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000134.png: 224x640 1 car, 2.9ms
# image 136/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000135.png: 224x640 1 car, 3.1ms
# image 137/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000136.png: 224x640 1 car, 2.9ms
# image 138/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000137.png: 224x640 1 car, 3.2ms
# image 139/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000138.png: 224x640 1 car, 2.9ms
# image 140/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000139.png: 224x640 1 car, 3.0ms
# image 141/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000140.png: 224x640 1 car, 3.0ms
# image 142/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000141.png: 224x640 1 car, 3.0ms
# image 143/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000142.png: 224x640 1 car, 2.9ms
# image 144/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000143.png: 224x640 1 car, 2.9ms
# image 145/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000144.png: 224x640 1 car, 2.9ms
# image 146/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000145.png: 224x640 1 car, 3.6ms
# image 147/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000146.png: 224x640 1 car, 2.9ms
# image 148/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000147.png: 224x640 1 car, 3.0ms
# image 149/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000148.png: 224x640 1 car, 4.1ms
# image 150/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000149.png: 224x640 1 car, 3.0ms
# image 151/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000150.png: 224x640 1 car, 3.1ms
# image 152/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000151.png: 224x640 1 car, 3.0ms
# image 153/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000152.png: 224x640 1 car, 3.9ms
# image 154/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000153.png: 224x640 1 car, 3.1ms
# image 155/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000154.png: 224x640 1 car, 3.0ms
# image 156/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000155.png: 224x640 1 car, 3.4ms
# image 157/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000156.png: 224x640 1 car, 1 truck, 2.9ms
# image 158/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000157.png: 224x640 1 car, 1 bus, 1 truck, 3.5ms
# image 159/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000158.png: 224x640 1 car, 1 bus, 1 truck, 3.1ms
# image 160/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000159.png: 224x640 1 car, 1 truck, 2.9ms
# image 161/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000160.png: 224x640 1 car, 1 truck, 3.2ms
# image 162/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000161.png: 224x640 2 cars, 1 truck, 2.9ms
# image 163/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000162.png: 224x640 2 cars, 1 bus, 3.6ms
# image 164/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000163.png: 224x640 2 cars, 1 truck, 3.0ms
# image 165/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000164.png: 224x640 2 cars, 1 truck, 3.0ms
# image 166/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000165.png: 224x640 3 cars, 1 truck, 3.0ms
# image 167/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000166.png: 224x640 2 cars, 1 truck, 2.9ms
# image 168/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000167.png: 224x640 2 cars, 1 truck, 3.0ms
# image 169/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000168.png: 224x640 2 cars, 1 bus, 3.0ms
# image 170/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000169.png: 224x640 1 car, 1 bus, 3.3ms
# image 171/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000170.png: 224x640 1 truck, 3.0ms
# image 172/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000171.png: 224x640 1 car, 2.9ms
# image 173/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000172.png: 224x640 4 cars, 3.3ms
# image 174/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000173.png: 224x640 4 cars, 2.9ms
# image 175/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000174.png: 224x640 3 cars, 2.9ms
# image 176/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000175.png: 224x640 4 cars, 3.5ms
# image 177/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000176.png: 224x640 4 cars, 2.9ms
# image 178/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000177.png: 224x640 5 cars, 2.9ms
# image 179/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000178.png: 224x640 6 cars, 2.9ms
# image 180/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000179.png: 224x640 7 cars, 3.0ms
# image 181/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000180.png: 224x640 3 cars, 3.7ms
# image 182/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000181.png: 224x640 6 cars, 3.0ms
# image 183/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000182.png: 224x640 7 cars, 2.9ms
# image 184/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000183.png: 224x640 6 cars, 2.9ms
# image 185/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000184.png: 224x640 7 cars, 2.9ms
# image 186/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000185.png: 224x640 8 cars, 3.0ms
# image 187/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000186.png: 224x640 7 cars, 3.7ms
# image 188/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000187.png: 224x640 6 cars, 2.9ms
# image 189/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000188.png: 224x640 6 cars, 2.9ms
# image 190/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000189.png: 224x640 6 cars, 2.9ms
# image 191/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000190.png: 224x640 6 cars, 3.0ms
# image 192/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000191.png: 224x640 4 cars, 3.2ms
# image 193/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000192.png: 224x640 3 cars, 2.9ms
# image 194/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000193.png: 224x640 4 cars, 3.3ms
# image 195/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000194.png: 224x640 4 cars, 2.9ms
# image 196/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000195.png: 224x640 5 cars, 2.9ms
# image 197/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000196.png: 224x640 5 cars, 3.7ms
# image 198/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000197.png: 224x640 5 cars, 2.9ms
# image 199/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000198.png: 224x640 4 cars, 3.6ms
# image 200/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000199.png: 224x640 4 cars, 2.9ms
# image 201/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000200.png: 224x640 4 cars, 2.9ms
# image 202/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000201.png: 224x640 4 cars, 2.9ms
# image 203/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000202.png: 224x640 4 cars, 2.9ms
# image 204/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000203.png: 224x640 3 cars, 3.2ms
# image 205/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000204.png: 224x640 2 cars, 3.0ms
# image 206/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000205.png: 224x640 2 cars, 3.0ms
# image 207/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000206.png: 224x640 3 cars, 3.0ms
# image 208/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000207.png: 224x640 3 cars, 3.0ms
# image 209/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000208.png: 224x640 3 cars, 4.0ms
# image 210/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000209.png: 224x640 3 cars, 3.0ms
# image 211/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000210.png: 224x640 3 cars, 3.4ms
# image 212/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000211.png: 224x640 3 cars, 3.0ms
# image 213/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000212.png: 224x640 3 cars, 3.3ms
# image 214/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000213.png: 224x640 3 cars, 3.4ms
# image 215/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000214.png: 224x640 3 cars, 3.0ms
# image 216/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000215.png: 224x640 3 cars, 3.0ms
# image 217/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000216.png: 224x640 4 cars, 2.9ms
# image 218/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000217.png: 224x640 4 cars, 3.0ms
# image 219/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000218.png: 224x640 3 cars, 3.0ms
# image 220/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000219.png: 224x640 3 cars, 2.9ms
# image 221/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000220.png: 224x640 3 cars, 3.2ms
# image 222/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000221.png: 224x640 3 cars, 3.1ms
# image 223/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000222.png: 224x640 5 cars, 2.9ms
# image 224/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000223.png: 224x640 4 cars, 3.2ms
# image 225/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000224.png: 224x640 4 cars, 2.9ms
# image 226/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000225.png: 224x640 4 cars, 3.6ms
# image 227/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000226.png: 224x640 4 cars, 3.0ms
# image 228/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000227.png: 224x640 4 cars, 2.9ms
# image 229/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000228.png: 224x640 4 cars, 3.0ms
# image 230/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000229.png: 224x640 4 cars, 3.4ms
# image 231/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000230.png: 224x640 4 cars, 3.0ms
# image 232/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000231.png: 224x640 4 cars, 3.0ms
# image 233/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000232.png: 224x640 4 cars, 3.7ms
# image 234/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000233.png: 224x640 3 cars, 2.9ms
# image 235/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000234.png: 224x640 3 cars, 3.0ms
# image 236/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000235.png: 224x640 3 cars, 2.9ms
# image 237/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000236.png: 224x640 3 cars, 3.0ms
# image 238/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000237.png: 224x640 3 cars, 3.6ms
# image 239/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000238.png: 224x640 3 cars, 3.0ms
# image 240/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000239.png: 224x640 3 cars, 2.9ms
# image 241/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000240.png: 224x640 3 cars, 2.9ms
# image 242/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000241.png: 224x640 3 cars, 2.9ms
# image 243/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000242.png: 224x640 3 cars, 3.1ms
# image 244/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000243.png: 224x640 2 cars, 1 truck, 2.9ms
# image 245/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000244.png: 224x640 2 cars, 1 truck, 3.0ms
# image 246/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000245.png: 224x640 2 cars, 1 truck, 2.9ms
# image 247/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000246.png: 224x640 2 cars, 1 truck, 2.9ms
# image 248/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000247.png: 224x640 3 cars, 1 truck, 3.8ms
# image 249/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000248.png: 224x640 3 cars, 1 bus, 2.9ms
# image 250/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000249.png: 224x640 3 cars, 1 bus, 1 truck, 3.0ms
# image 251/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000250.png: 224x640 3 cars, 1 truck, 2.9ms
# image 252/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000251.png: 224x640 3 cars, 1 truck, 2.9ms
# image 253/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000252.png: 224x640 2 cars, 1 truck, 3.0ms
# image 254/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000253.png: 224x640 2 cars, 1 truck, 3.0ms
# image 255/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000254.png: 224x640 2 cars, 1 truck, 3.5ms
# image 256/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000255.png: 224x640 2 cars, 1 truck, 2.9ms
# image 257/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000256.png: 224x640 2 cars, 1 truck, 3.3ms
# image 258/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000257.png: 224x640 3 cars, 1 truck, 3.2ms
# image 259/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000258.png: 224x640 3 cars, 2.9ms
# image 260/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000259.png: 224x640 3 cars, 2.9ms
# image 261/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000260.png: 224x640 4 cars, 2.9ms
# image 262/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000261.png: 224x640 5 cars, 3.1ms
# image 263/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000262.png: 224x640 5 cars, 2.9ms
# image 264/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000263.png: 224x640 5 cars, 3.7ms
# image 265/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000264.png: 224x640 5 cars, 2.9ms
# image 266/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000265.png: 224x640 6 cars, 3.2ms
# image 267/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000266.png: 224x640 5 cars, 3.4ms
# image 268/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000267.png: 224x640 5 cars, 3.6ms
# image 269/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000268.png: 224x640 4 cars, 3.0ms
# image 270/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000269.png: 224x640 6 cars, 2.9ms
# image 271/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000270.png: 224x640 6 cars, 2.9ms
# image 272/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000271.png: 224x640 6 cars, 2.9ms
# image 273/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000272.png: 224x640 6 cars, 4.1ms
# image 274/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000273.png: 224x640 7 cars, 2.9ms
# image 275/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000274.png: 224x640 5 cars, 2.9ms
# image 276/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000275.png: 224x640 4 cars, 3.0ms
# image 277/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000276.png: 224x640 4 cars, 2.9ms
# image 278/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000277.png: 224x640 5 cars, 2.9ms
# image 279/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000278.png: 224x640 5 cars, 2.9ms
# image 280/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000279.png: 224x640 5 cars, 2.9ms
# image 281/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000280.png: 224x640 5 cars, 3.0ms
# image 282/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000281.png: 224x640 4 cars, 2.9ms
# image 283/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000282.png: 224x640 3 cars, 3.7ms
# image 284/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000283.png: 224x640 3 cars, 2.9ms
# image 285/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000284.png: 224x640 3 cars, 3.0ms
# image 286/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000285.png: 224x640 3 cars, 3.0ms
# image 287/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000286.png: 224x640 3 cars, 3.0ms
# image 288/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000287.png: 224x640 2 cars, 2.8ms
# image 289/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000288.png: 224x640 3 cars, 2.9ms
# image 290/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000289.png: 224x640 2 cars, 2.9ms
# image 291/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000290.png: 224x640 3 cars, 2.9ms
# image 292/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000291.png: 224x640 2 cars, 2.9ms
# image 293/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000292.png: 224x640 1 car, 2.9ms
# image 294/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000293.png: 224x640 1 car, 7.6ms
# image 295/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000294.png: 224x640 1 car, 3.1ms
# image 296/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000295.png: 224x640 1 car, 3.2ms
# image 297/297 /home/seanachan/ByteTrack_ultralytics/refer-kitti/KITTI/training/image_02/0005/000296.png: 224x640 1 car, 3.3ms
# Speed: 0.7ms preprocess, 3.2ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 640)

# %%
if results:
    # Access the Results object for the first frame
    first_frame_results = results[0]

    # Check if there are any detected boxes in the first frame
    if first_frame_results.boxes is not None:
        print("Detections and Tracks for the First Frame:")
        for box in first_frame_results.boxes:
            # Bounding box coordinates (xyxy format)
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
            print("id: ",box.id[0])

            # Class ID and Name
            class_id = int(box.cls[0].cpu().numpy())
            class_name = first_frame_results.names[class_id]

            # Confidence Score
            confidence = float(box.conf[0].cpu().numpy())

            # Tracker ID (important for tracking results)
            tracker_id = int(box.id[0].cpu().numpy()) if box.id is not None else "N/A"

            print(f"  Object ID: {tracker_id}, Class: {class_name} (ID: {class_id}), Confidence: {confidence:.2f}, BBox: [{x1}, {y1}, {x2}, {y2}]")
    else:
        print("No detections in the first frame.")
else:
    print("No results found. Ensure model.track() was executed successfully.")
# Out:
# Detections and Tracks for the First Frame:
# id:  tensor(1.)
#   Object ID: 1, Class: car (ID: 2), Confidence: 0.63, BBox: [254, 175, 302, 201]
# id:  tensor(2.)
#   Object ID: 2, Class: car (ID: 2), Confidence: 0.54, BBox: [569, 171, 609, 207]
# id:  tensor(3.)
#   Object ID: 3, Class: car (ID: 2), Confidence: 0.37, BBox: [321, 178, 351, 196]

# %%
import json

# helper function to crop the detected objects from the frame
def write_gt(gt_path, save_path, expression_path, labels_path, video_id, expression):
  save_format = "{frame},{id},{x1},{y1},{w},{h},1, 1, 1\n"

  with open(os.path.join(expression_path, video_id, expression+".json")) as f:
      json_info = json.load(f)

  # FIX: Get image dimensions from the first available frame
  ORI_PATH = f"{HOME}/refer-kitti/KITTI/training/image_02/{video_id}"
  first_frame_id = int(list(json_info["label"].keys())[0])
  img_path = os.path.join(ORI_PATH, f"{first_frame_id:06d}.png")
  img = cv2.imread(img_path)
  seq_h, seq_w, _ = img.shape

  labels_path = os.path.join(labels_path, video_id)
  if(not os.path.exists(os.path.join(save_path,video_id,expression)) ):
    os.mkdir(os.path.join(save_path,video_id,expression))
#   print(f"json_info:{json_info}")
  with open(os.path.join(save_path, video_id, expression, "gt.txt"), "w") as f:
      for k in json_info["label"].keys():
          frame_id = int(k)
          if not os.path.isfile(
              os.path.join(labels_path, "{:06d}.txt".format(frame_id))
          ):
              continue
          frame_gt = np.loadtxt(
              os.path.join(labels_path, "{:06d}.txt".format(frame_id))
          ).reshape(-1, 6)
          for frame_gt_line in frame_gt:
              aa = json_info["label"][k]  # all gt from frame
              aa = [int(a) for a in aa]
              if int(frame_gt_line[1]) in aa:  # choose referent gt from all gt
                  track_id = int(frame_gt_line[1])
                  x1, y1, w, h = frame_gt_line[2:6]  # KITTI -> [x1, y1, w, h]
                  line = save_format.format(
                      frame=frame_id + 1,
                      id=track_id,
                      x1=x1 * seq_w,
                      y1=y1 * seq_h,
                      w=w * seq_w,
                      h=h * seq_h,
                  )
                  f.write(line)

#   print("save gt to {}".format(os.path.join(save_path, video_id, expression, "gt.txt")))

# %%
def save_crops_from_detections(box, frame_id, crops_dir):
  """Save cropped images of detected objects for LLM analysis."""
  ORI_PATH = f"{HOME}/refer-kitti/KITTI/training/image_02/0005"
  img_path = os.path.join(ORI_PATH, f"{frame_id-1:06d}.png")
  img = cv2.imread(img_path)
  
  seq_h, seq_w, _ = img.shape

  os.makedirs(crops_dir, exist_ok=True)
  x1, y1, x2, y2 = list(map(int, box.xyxy[0]))
  crop = img[y1:y2, x1:x2]
  if crop.size > 0:  # Make sure crop is valid
      save_path = os.path.join(crops_dir, f"i{int(box.id[0])}_f{frame_id}.jpg")
      cv2.imwrite(save_path, crop)

# %%
from dataclasses import dataclass

@dataclass
class Crop_Img:
    frame_id: int
    tracker_id: int
    bbox: dict  # {'x1': ..., 'y1': ..., 'x2': ..., 'y2': ...}
    width: int
    height: int
    crop_path: str
    
    @property
    def x1(self):
        return self.bbox.get('x1', 0)
    
    @property
    def y1(self):
        return self.bbox.get('y1', 0)
    
    @property
    def x2(self):
        return self.bbox.get('x2', 0)
    
    @property
    def y2(self):
        return self.bbox.get('y2', 0)

# %%
import os, json, cv2
import shutil
from LLM import select_targets

def inference(EXP_PATH, EXPRESSION_PATH, seq, results):
    SEQ_PATH = os.path.join(EXPRESSION_PATH, seq[0], seq[1])
    save_format = "{frame},{id},{x1},{y1},{w},{h},1,1,1\n"
    with open(SEQ_PATH, "r", encoding="utf-8") as f:
        prompt = json.load(f)
        sentence = prompt.get("sentence", "")

    expression_str = seq[1].split(".")[0]
    exp_dir = os.path.join(EXP_PATH, seq[0], expression_str)
    os.makedirs(exp_dir, exist_ok=True)
    predict_path = os.path.join(exp_dir, "predict.txt")

    os.makedirs("crops/", exist_ok=True)

    first_frame_path = os.path.join(KITTI_PATH, seq[0], f"{1:06d}.png")
    img = cv2.imread(first_frame_path)
    seq_h, seq_w = img.shape[:2]
    existing_ids = set()  # To keep track of existing tracker IDs
    with open(predict_path, "w") as fout:
      for frame_idx, result in enumerate(results, start=1):
        # save crops for this frame
        crop_imgs = []
        for box in result.boxes:
          save_crops_from_detections(box, frame_idx, "crops/")
          # print(list(map(int, box.xyxy[0])))
          # Record bounding box position
          x1, y1, x2, y2 = list(map(float, box.xyxy[0]))
          tracker_id = int(box.id[0]) if box.id is not None else -1

          # Create Crop_Img object using the defined class
          crop_img_obj = Crop_Img(
            frame_id=frame_idx,
            tracker_id=tracker_id,
            bbox={"x1": x1, "y1": y1, "x2": x2, "y2": y2},
            width=x2 - x1,
            height=y2 - y1,
            crop_path=os.path.join(
              "crops/", f"i{tracker_id}_f{frame_idx}.jpg"
            ),
          )
          crop_imgs.append(crop_img_obj)

        # Call select_targets once every 30 frames
        if (frame_idx-1) % 30 == 0 and crop_imgs:
          matches = select_targets(
            crops_dir="crops/",
            prompt=sentence,
            device="cuda:0",
            quiet=False,
            img_size={"img_h": seq_h, "img_w": seq_w},
            crop_info=crop_imgs,  # Pass list of Crop_Img objects
          )
          existing_ids.update(match for match in matches)  # Update existing IDs
        else:
          matches = existing_ids  # Keep track of existing IDs

        # Write predictions for matched objects with actual bounding boxes
        for crop_img in crop_imgs:
          if crop_img.tracker_id in matches:
            x1 = crop_img.bbox['x1']
            y1 = crop_img.bbox['y1']
            w = crop_img.width
            h = crop_img.height
            
            line = save_format.format(
              frame=frame_idx,
              id=crop_img.tracker_id,
              x1=x1,
              y1=y1,
              w=w,
              h=h
            )
            print(f"Frame {frame_idx}, ID {crop_img.tracker_id}: x1={x1}, y1={y1}, w={w}, h={h}")
            fout.write(line)
          
        # Clean up crops directory
        if os.path.exists("crops/"):
          shutil.rmtree("crops/")
        os.makedirs("crops/", exist_ok=True)

# %%
import importlib
import LLM
importlib.reload(LLM)
from LLM import select_targets

# %%
! cd {HOME}
result_num = 1
EXPRESSION_PATH = os.path.join(HOME, f"refer-kitti/expression/") 
GT_PATH = os.path.join(HOME, f"refer-kitti/KITTI/labels_with_ids/image_02/")
EXP_PATH = os.path.join(HOME, f"exps/results_{result_num}/")
LABELS_PATH = os.path.join(HOME, f"refer-kitti/KITTI/labels_with_ids/image_02/")

EXP_NUM = "0005"
images_dir = os.path.join(KITTI_PATH, EXP_NUM)
sequence_id = os.path.basename(images_dir.rstrip("/"))
expression_dir = os.path.join(KITTI_PATH, EXP_NUM)
sentence = ""
if "refer-kitti-v2" in EXPRESSION_PATH:
    video_ids = ["0005", "0011", "0013", "0019"]
else:
    video_ids = ["0005", "0011", "0013"]

for video_id in video_ids[1:]:
    expression_jsons = sorted(os.listdir(os.path.join(EXPRESSION_PATH, video_id)))
    
    seq_nums = []
    for expression_json in expression_jsons:
        seq_nums.append([video_id, expression_json])
    
    for seq_num in seq_nums:
        write_gt(GT_PATH, EXP_PATH, EXPRESSION_PATH, LABELS_PATH, seq_num[0], seq_num[1].split(".")[0])
        inference(EXP_PATH, EXPRESSION_PATH, seq_num, results)
        

# print(seq_nums[:3])
# expression_num = len(seq_nums)
# print(expression_num)
# Out:
# [INFO] (1/6) Processing i1_f1.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i1_f1.jpg
# crop_details: the position of this crop in the original image is (x1: 254, y1: 175, x2: 302, y2: 201).
# [DEBUG] LLM response: no
# [INFO] (2/6) Processing i2_f1.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f1.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f1.jpg
# crop_details: the position of this crop in the original image is (x1: 569, y1: 171, x2: 609, y2: 207).
# [DEBUG] LLM response: no
# [INFO] (2/6) Processing i2_f1.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f1.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f1.jpg
# crop_details: the position of this crop in the original image is (x1: 569, y1: 171, x2: 609, y2: 207).
# [DEBUG] LLM response: no
# [INFO] (3/6) Processing i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# crop_details: the position of this crop in the original image is (x1: 321, y1: 178, x2: 351, y2: 196).
# [DEBUG] LLM response: no
# [INFO] (3/6) Processing i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i3_f1.jpg
# crop_details: the position of this crop in the original image is (x1: 321, y1: 178, x2: 351, y2: 196).
# [DEBUG] LLM response: no
# [INFO] (4/6) Processing i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# crop_details:
# [DEBUG] LLM response: no
# [INFO] (4/6) Processing i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# crop_details:
# [DEBUG] LLM response: yes
# [RESULT] Target ID: 2 selected
# [INFO] (5/6) Processing i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# crop_details:
# [DEBUG] LLM response: yes
# [RESULT] Target ID: 2 selected
# [INFO] (5/6) Processing i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# crop_details:
# [DEBUG] LLM response: yes
# [RESULT] Target ID: 8 selected
# [INFO] (6/6) Processing i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# crop_details:
# [DEBUG] LLM response: yes
# [RESULT] Target ID: 8 selected
# [INFO] (6/6) Processing i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=1, bbox={'x1': 254, 'y1': 175, 'x2': 302, 'y2': 201}, width=48, height=26, crop_path='crops/i1_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=2, bbox={'x1': 569, 'y1': 171, 'x2': 609, 'y2': 207}, width=40, height=36, crop_path='crops/i2_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=1, tracker_id=3, bbox={'x1': 321, 'y1': 178, 'x2': 351, 'y2': 196}, width=30, height=18, crop_path='crops/i3_f1.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# crop_details:
# [DEBUG] LLM response: no
# Frame 1, ID 2: x1=569, y1=171, w=40, h=36
# Frame 2, ID 2: x1=571, y1=172, w=37, h=33
# Frame 3, ID 2: x1=570, y1=170, w=39, h=35
# Frame 4, ID 2: x1=568, y1=168, w=44, h=38
# Frame 5, ID 2: x1=569, y1=168, w=42, h=38
# Frame 5, ID 8: x1=288, y1=173, w=35, h=22
# Frame 6, ID 2: x1=568, y1=167, w=44, h=38
# Frame 6, ID 8: x1=285, y1=173, w=36, h=21
# Frame 7, ID 2: x1=567, y1=164, w=46, h=41
# Frame 8, ID 2: x1=569, y1=166, w=43, h=39
# Frame 9, ID 2: x1=569, y1=169, w=43, h=38
# [DEBUG] LLM response: no
# Frame 1, ID 2: x1=569, y1=171, w=40, h=36
# Frame 2, ID 2: x1=571, y1=172, w=37, h=33
# Frame 3, ID 2: x1=570, y1=170, w=39, h=35
# Frame 4, ID 2: x1=568, y1=168, w=44, h=38
# Frame 5, ID 2: x1=569, y1=168, w=42, h=38
# Frame 5, ID 8: x1=288, y1=173, w=35, h=22
# Frame 6, ID 2: x1=568, y1=167, w=44, h=38
# Frame 6, ID 8: x1=285, y1=173, w=36, h=21
# Frame 7, ID 2: x1=567, y1=164, w=46, h=41
# Frame 8, ID 2: x1=569, y1=166, w=43, h=39
# Frame 9, ID 2: x1=569, y1=169, w=43, h=38
# Frame 10, ID 2: x1=570, y1=171, w=42, h=38
# Frame 11, ID 2: x1=570, y1=172, w=42, h=38
# Frame 12, ID 2: x1=570, y1=172, w=43, h=40
# Frame 13, ID 2: x1=570, y1=172, w=44, h=41
# Frame 14, ID 2: x1=571, y1=172, w=43, h=41
# Frame 15, ID 2: x1=571, y1=170, w=44, h=42
# Frame 16, ID 2: x1=572, y1=172, w=42, h=39
# Frame 17, ID 2: x1=573, y1=171, w=41, h=39
# Frame 18, ID 2: x1=573, y1=169, w=41, h=40
# Frame 10, ID 2: x1=570, y1=171, w=42, h=38
# Frame 11, ID 2: x1=570, y1=172, w=42, h=38
# Frame 12, ID 2: x1=570, y1=172, w=43, h=40
# Frame 13, ID 2: x1=570, y1=172, w=44, h=41
# Frame 14, ID 2: x1=571, y1=172, w=43, h=41
# Frame 15, ID 2: x1=571, y1=170, w=44, h=42
# Frame 16, ID 2: x1=572, y1=172, w=42, h=39
# Frame 17, ID 2: x1=573, y1=171, w=41, h=39
# Frame 18, ID 2: x1=573, y1=169, w=41, h=40
# Frame 19, ID 2: x1=571, y1=168, w=43, h=42
# Frame 20, ID 2: x1=571, y1=169, w=42, h=41
# Frame 21, ID 2: x1=571, y1=171, w=41, h=40
# Frame 22, ID 2: x1=570, y1=171, w=43, h=41
# Frame 23, ID 2: x1=570, y1=170, w=43, h=41
# Frame 23, ID 8: x1=276, y1=173, w=40, h=23
# Frame 24, ID 2: x1=569, y1=168, w=43, h=42
# Frame 24, ID 8: x1=268, y1=174, w=40, h=22
# Frame 25, ID 2: x1=569, y1=167, w=43, h=43
# Frame 25, ID 8: x1=255, y1=172, w=45, h=26
# Frame 26, ID 2: x1=569, y1=167, w=43, h=42
# Frame 26, ID 8: x1=247, y1=174, w=43, h=23
# Frame 27, ID 2: x1=568, y1=167, w=44, h=42
# Frame 27, ID 8: x1=228, y1=174, w=49, h=26
# Frame 28, ID 2: x1=568, y1=168, w=44, h=42
# Frame 28, ID 8: x1=212, y1=174, w=52, h=27
# Frame 19, ID 2: x1=571, y1=168, w=43, h=42
# Frame 20, ID 2: x1=571, y1=169, w=42, h=41
# Frame 21, ID 2: x1=571, y1=171, w=41, h=40
# Frame 22, ID 2: x1=570, y1=171, w=43, h=41
# Frame 23, ID 2: x1=570, y1=170, w=43, h=41
# Frame 23, ID 8: x1=276, y1=173, w=40, h=23
# Frame 24, ID 2: x1=569, y1=168, w=43, h=42
# Frame 24, ID 8: x1=268, y1=174, w=40, h=22
# Frame 25, ID 2: x1=569, y1=167, w=43, h=43
# Frame 25, ID 8: x1=255, y1=172, w=45, h=26
# Frame 26, ID 2: x1=569, y1=167, w=43, h=42
# Frame 26, ID 8: x1=247, y1=174, w=43, h=23
# Frame 27, ID 2: x1=568, y1=167, w=44, h=42
# Frame 27, ID 8: x1=228, y1=174, w=49, h=26
# Frame 28, ID 2: x1=568, y1=168, w=44, h=42
# Frame 28, ID 8: x1=212, y1=174, w=52, h=27
# Frame 29, ID 2: x1=568, y1=169, w=44, h=42
# Frame 29, ID 8: x1=195, y1=174, w=56, h=28
# Frame 30, ID 2: x1=568, y1=168, w=44, h=42
# Frame 30, ID 8: x1=177, y1=174, w=58, h=29
# [INFO] (1/3) Processing i2_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 569, y1: 167, x2: 612, y2: 209).
# Frame 29, ID 2: x1=568, y1=169, w=44, h=42
# Frame 29, ID 8: x1=195, y1=174, w=56, h=28
# Frame 30, ID 2: x1=568, y1=168, w=44, h=42
# Frame 30, ID 8: x1=177, y1=174, w=58, h=29
# [INFO] (1/3) Processing i2_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 569, y1: 167, x2: 612, y2: 209).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=51, bbox={'x1': 338, 'y1': 166, 'x2': 381, 'y2': 185}, width=43, height=19, crop_path='crops/i51_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=8, bbox={'x1': 158, 'y1': 173, 'x2': 219, 'y2': 203}, width=61, height=30, crop_path='crops/i8_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 158, y1: 173, x2: 219, y2: 203).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=51, bbox={'x1': 338, 'y1': 166, 'x2': 381, 'y2': 185}, width=43, height=19, crop_path='crops/i51_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# Crop_Img(frame_id=31, tracker_id=8, bbox={'x1': 158, 'y1': 173, 'x2': 219, 'y2': 203}, width=61, height=30, crop_path='crops/i8_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i8_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 158, y1: 173, x2: 219, y2: 203).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i51_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=31, tracker_id=51, bbox={'x1': 338, 'y1': 166, 'x2': 381, 'y2': 185}, width=43, height=19, crop_path='crops/i51_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 338, y1: 166, x2: 381, y2: 185).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i51_f31.jpg
# Crop_Img(frame_id=31, tracker_id=2, bbox={'x1': 569, 'y1': 167, 'x2': 612, 'y2': 209}, width=43, height=42, crop_path='crops/i2_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# Crop_Img(frame_id=31, tracker_id=51, bbox={'x1': 338, 'y1': 166, 'x2': 381, 'y2': 185}, width=43, height=19, crop_path='crops/i51_f31.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f31.jpg
# crop_details: the position of this crop in the original image is (x1: 338, y1: 166, x2: 381, y2: 185).
# [DEBUG] LLM response: no
# Frame 32, ID 2: x1=569, y1=167, w=43, h=41
# Frame 32, ID 8: x1=138, y1=172, w=66, h=32
# Frame 33, ID 2: x1=569, y1=167, w=43, h=41
# Frame 33, ID 8: x1=114, y1=171, w=73, h=35
# Frame 34, ID 2: x1=567, y1=167, w=45, h=43
# Frame 34, ID 8: x1=89, y1=171, w=80, h=37
# Frame 35, ID 2: x1=567, y1=169, w=46, h=43
# Frame 35, ID 8: x1=63, y1=171, w=87, h=40
# Frame 36, ID 2: x1=566, y1=168, w=48, h=46
# Frame 36, ID 8: x1=34, y1=172, w=95, h=43
# Frame 37, ID 2: x1=566, y1=168, w=49, h=46
# [DEBUG] LLM response: no
# Frame 32, ID 2: x1=569, y1=167, w=43, h=41
# Frame 32, ID 8: x1=138, y1=172, w=66, h=32
# Frame 33, ID 2: x1=569, y1=167, w=43, h=41
# Frame 33, ID 8: x1=114, y1=171, w=73, h=35
# Frame 34, ID 2: x1=567, y1=167, w=45, h=43
# Frame 34, ID 8: x1=89, y1=171, w=80, h=37
# Frame 35, ID 2: x1=567, y1=169, w=46, h=43
# Frame 35, ID 8: x1=63, y1=171, w=87, h=40
# Frame 36, ID 2: x1=566, y1=168, w=48, h=46
# Frame 36, ID 8: x1=34, y1=172, w=95, h=43
# Frame 37, ID 2: x1=566, y1=168, w=49, h=46
# Frame 38, ID 2: x1=566, y1=166, w=49, h=47
# Frame 39, ID 2: x1=566, y1=166, w=49, h=47
# Frame 40, ID 2: x1=567, y1=167, w=48, h=47
# Frame 41, ID 2: x1=568, y1=168, w=48, h=46
# Frame 42, ID 2: x1=569, y1=170, w=46, h=44
# Frame 43, ID 2: x1=568, y1=171, w=48, h=44
# Frame 44, ID 2: x1=568, y1=171, w=48, h=45
# Frame 38, ID 2: x1=566, y1=166, w=49, h=47
# Frame 39, ID 2: x1=566, y1=166, w=49, h=47
# Frame 40, ID 2: x1=567, y1=167, w=48, h=47
# Frame 41, ID 2: x1=568, y1=168, w=48, h=46
# Frame 42, ID 2: x1=569, y1=170, w=46, h=44
# Frame 43, ID 2: x1=568, y1=171, w=48, h=44
# Frame 44, ID 2: x1=568, y1=171, w=48, h=45
# Frame 45, ID 2: x1=569, y1=171, w=48, h=45
# Frame 46, ID 2: x1=570, y1=171, w=48, h=45
# Frame 47, ID 2: x1=571, y1=173, w=47, h=44
# Frame 48, ID 2: x1=570, y1=173, w=50, h=46
# Frame 49, ID 2: x1=571, y1=174, w=50, h=46
# Frame 50, ID 2: x1=571, y1=174, w=50, h=46
# Frame 51, ID 2: x1=571, y1=174, w=49, h=46
# Frame 45, ID 2: x1=569, y1=171, w=48, h=45
# Frame 46, ID 2: x1=570, y1=171, w=48, h=45
# Frame 47, ID 2: x1=571, y1=173, w=47, h=44
# Frame 48, ID 2: x1=570, y1=173, w=50, h=46
# Frame 49, ID 2: x1=571, y1=174, w=50, h=46
# Frame 50, ID 2: x1=571, y1=174, w=50, h=46
# Frame 51, ID 2: x1=571, y1=174, w=49, h=46
# Frame 52, ID 2: x1=571, y1=174, w=50, h=47
# Frame 53, ID 2: x1=572, y1=174, w=50, h=47
# Frame 54, ID 2: x1=572, y1=174, w=51, h=47
# Frame 55, ID 2: x1=572, y1=174, w=51, h=47
# Frame 56, ID 2: x1=573, y1=172, w=52, h=48
# Frame 57, ID 2: x1=574, y1=174, w=51, h=47
# Frame 58, ID 2: x1=574, y1=172, w=53, h=50
# Frame 52, ID 2: x1=571, y1=174, w=50, h=47
# Frame 53, ID 2: x1=572, y1=174, w=50, h=47
# Frame 54, ID 2: x1=572, y1=174, w=51, h=47
# Frame 55, ID 2: x1=572, y1=174, w=51, h=47
# Frame 56, ID 2: x1=573, y1=172, w=52, h=48
# Frame 57, ID 2: x1=574, y1=174, w=51, h=47
# Frame 58, ID 2: x1=574, y1=172, w=53, h=50
# Frame 59, ID 2: x1=574, y1=173, w=53, h=49
# Frame 60, ID 2: x1=575, y1=173, w=53, h=49
# [INFO] (1/5) Processing i2_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 576, y1: 173, x2: 628, y2: 221).
# Frame 59, ID 2: x1=574, y1=173, w=53, h=49
# Frame 60, ID 2: x1=575, y1=173, w=53, h=49
# [INFO] (1/5) Processing i2_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 576, y1: 173, x2: 628, y2: 221).
# [DEBUG] LLM response: no
# [INFO] (2/5) Processing i51_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 79, y1: 171, x2: 155, y2: 212).
# [DEBUG] LLM response: no
# [INFO] (2/5) Processing i51_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i51_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 79, y1: 171, x2: 155, y2: 212).
# [DEBUG] LLM response: no
# [INFO] (3/5) Processing i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=123, bbox={'x1': 0, 'y1': 181, 'x2': 80, 'y2': 218}, width=80, height=37, crop_path='crops/i123_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=101, bbox={'x1': 353, 'y1': 168, 'x2': 385, 'y2': 187}, width=32, height=19, crop_path='crops/i101_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 353, y1: 168, x2: 385, y2: 187).
# [DEBUG] LLM response: no
# [INFO] (3/5) Processing i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=123, bbox={'x1': 0, 'y1': 181, 'x2': 80, 'y2': 218}, width=80, height=37, crop_path='crops/i123_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# Crop_Img(frame_id=61, tracker_id=101, bbox={'x1': 353, 'y1': 168, 'x2': 385, 'y2': 187}, width=32, height=19, crop_path='crops/i101_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 353, y1: 168, x2: 385, y2: 187).
# [DEBUG] LLM response: no
# [INFO] (4/5) Processing i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 358, y1: 169, x2: 394, y2: 187).
# [DEBUG] LLM response: no
# [INFO] (4/5) Processing i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 358, y1: 169, x2: 394, y2: 187).
# [DEBUG] LLM response: no
# [INFO] (5/5) Processing i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=123, bbox={'x1': 0, 'y1': 181, 'x2': 80, 'y2': 218}, width=80, height=37, crop_path='crops/i123_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 0, y1: 181, x2: 80, y2: 218).
# [DEBUG] LLM response: no
# [INFO] (5/5) Processing i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=2, bbox={'x1': 576, 'y1': 173, 'x2': 628, 'y2': 221}, width=52, height=48, crop_path='crops/i2_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=51, bbox={'x1': 79, 'y1': 171, 'x2': 155, 'y2': 212}, width=76, height=41, crop_path='crops/i51_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=117, bbox={'x1': 358, 'y1': 169, 'x2': 394, 'y2': 187}, width=36, height=18, crop_path='crops/i117_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# Crop_Img(frame_id=61, tracker_id=123, bbox={'x1': 0, 'y1': 181, 'x2': 80, 'y2': 218}, width=80, height=37, crop_path='crops/i123_f61.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i123_f61.jpg
# crop_details: the position of this crop in the original image is (x1: 0, y1: 181, x2: 80, y2: 218).
# [DEBUG] LLM response: no
# Frame 62, ID 2: x1=576, y1=171, w=53, h=49
# Frame 63, ID 2: x1=576, y1=171, w=54, h=49
# Frame 64, ID 2: x1=577, y1=172, w=54, h=49
# Frame 65, ID 2: x1=576, y1=171, w=56, h=51
# Frame 66, ID 2: x1=577, y1=171, w=56, h=52
# Frame 67, ID 2: x1=578, y1=173, w=54, h=50
# [DEBUG] LLM response: no
# Frame 62, ID 2: x1=576, y1=171, w=53, h=49
# Frame 63, ID 2: x1=576, y1=171, w=54, h=49
# Frame 64, ID 2: x1=577, y1=172, w=54, h=49
# Frame 65, ID 2: x1=576, y1=171, w=56, h=51
# Frame 66, ID 2: x1=577, y1=171, w=56, h=52
# Frame 67, ID 2: x1=578, y1=173, w=54, h=50
# Frame 68, ID 2: x1=578, y1=172, w=56, h=51
# Frame 69, ID 2: x1=579, y1=173, w=55, h=51
# Frame 70, ID 2: x1=579, y1=173, w=55, h=51
# Frame 71, ID 2: x1=580, y1=173, w=55, h=51
# Frame 72, ID 2: x1=581, y1=174, w=54, h=50
# Frame 73, ID 2: x1=581, y1=173, w=55, h=51
# Frame 74, ID 2: x1=582, y1=174, w=54, h=51
# Frame 75, ID 2: x1=582, y1=174, w=55, h=51
# Frame 68, ID 2: x1=578, y1=172, w=56, h=51
# Frame 69, ID 2: x1=579, y1=173, w=55, h=51
# Frame 70, ID 2: x1=579, y1=173, w=55, h=51
# Frame 71, ID 2: x1=580, y1=173, w=55, h=51
# Frame 72, ID 2: x1=581, y1=174, w=54, h=50
# Frame 73, ID 2: x1=581, y1=173, w=55, h=51
# Frame 74, ID 2: x1=582, y1=174, w=54, h=51
# Frame 75, ID 2: x1=582, y1=174, w=55, h=51
# Frame 76, ID 2: x1=582, y1=174, w=54, h=50
# Frame 77, ID 2: x1=582, y1=174, w=55, h=50
# Frame 78, ID 2: x1=583, y1=175, w=54, h=50
# Frame 79, ID 2: x1=583, y1=174, w=55, h=50
# Frame 80, ID 2: x1=582, y1=175, w=55, h=50
# Frame 81, ID 2: x1=582, y1=175, w=56, h=50
# Frame 82, ID 2: x1=582, y1=175, w=56, h=50
# Frame 83, ID 2: x1=582, y1=175, w=56, h=50
# Frame 84, ID 2: x1=582, y1=175, w=56, h=50
# Frame 76, ID 2: x1=582, y1=174, w=54, h=50
# Frame 77, ID 2: x1=582, y1=174, w=55, h=50
# Frame 78, ID 2: x1=583, y1=175, w=54, h=50
# Frame 79, ID 2: x1=583, y1=174, w=55, h=50
# Frame 80, ID 2: x1=582, y1=175, w=55, h=50
# Frame 81, ID 2: x1=582, y1=175, w=56, h=50
# Frame 82, ID 2: x1=582, y1=175, w=56, h=50
# Frame 83, ID 2: x1=582, y1=175, w=56, h=50
# Frame 84, ID 2: x1=582, y1=175, w=56, h=50
# Frame 85, ID 2: x1=582, y1=175, w=56, h=50
# Frame 86, ID 2: x1=583, y1=176, w=55, h=49
# Frame 87, ID 2: x1=584, y1=175, w=54, h=49
# Frame 88, ID 2: x1=583, y1=174, w=53, h=47
# Frame 89, ID 2: x1=582, y1=173, w=54, h=48
# Frame 90, ID 2: x1=582, y1=173, w=53, h=47
# [INFO] (1/4) Processing i2_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 582, y1: 173, x2: 635, y2: 220).
# Frame 85, ID 2: x1=582, y1=175, w=56, h=50
# Frame 86, ID 2: x1=583, y1=176, w=55, h=49
# Frame 87, ID 2: x1=584, y1=175, w=54, h=49
# Frame 88, ID 2: x1=583, y1=174, w=53, h=47
# Frame 89, ID 2: x1=582, y1=173, w=54, h=48
# Frame 90, ID 2: x1=582, y1=173, w=53, h=47
# [INFO] (1/4) Processing i2_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 582, y1: 173, x2: 635, y2: 220).
# [DEBUG] LLM response: The crop region specified is defined by coordinates:
# - **X-axis**: 582 (left) to 635 (right)
# - **Y-axis**: 173 (top) to 220 (bottom)
#
# ### Analysis of the Crop's Position
# 1. **Image Width Context**
#    - Total image width = 1242 pixels.
#    - The **center** of the image is at `1242 / 2 = 621` pixels from the left edge.
#    - The crop spans from **582** (39 pixels left of the center) to **635** (14 pixels right of the center).
#    - Thus, the crop is centered **slightly to the left** of the image’s midpoint, spanning across the center point (621).
#
# 2. **"Black Cars in Right" Requirement Interpretation**
#    - The phrase *"black cars in right"* implies the crop should be positioned on the **right side of the image** (i.e., toward the right edge) or the **right side of the car** itself.
#    - However, the crop’s x-values (582–635) fall **well within the left half of the image** (since 582 < 621).
#    - The right edge of the image is at **1242**, and the crop only reaches up to **635**, which is still **left of the center** (621).
#
# 3. **Car-Specific Perspective**
#    - If the car is centered in the image (a reasonable assumption for a rear-view photo), its body would span approximately symmetrically around the center (621).
#    - A crop located at **582–635** would lie **within the left portion of the car’s body**, not its right side.
#    - For the crop to represent the *right side of the car*, it would need to have an x-range closer to the right edge of the image (e.g., > 900), but this is not the case here.
#
# ### Conclusion
# The crop region **(582–635, 173–220)** is centered around the **left half of the image**, not the right side. While it does contain part of a black car (as described), it **does not satisfy the requirement** of being located on the **right side of the image** or the **right side of the car**.
#
# ✅ **Answer**: **No**, the crop is **not** "black cars in right" — it is positioned **left of the image center**, not on the right.
# [INFO] (2/4) Processing i101_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 94, y1: 171, x2: 176, y2: 207).
# [DEBUG] LLM response: The crop region specified is defined by coordinates:
# - **X-axis**: 582 (left) to 635 (right)
# - **Y-axis**: 173 (top) to 220 (bottom)
#
# ### Analysis of the Crop's Position
# 1. **Image Width Context**
#    - Total image width = 1242 pixels.
#    - The **center** of the image is at `1242 / 2 = 621` pixels from the left edge.
#    - The crop spans from **582** (39 pixels left of the center) to **635** (14 pixels right of the center).
#    - Thus, the crop is centered **slightly to the left** of the image’s midpoint, spanning across the center point (621).
#
# 2. **"Black Cars in Right" Requirement Interpretation**
#    - The phrase *"black cars in right"* implies the crop should be positioned on the **right side of the image** (i.e., toward the right edge) or the **right side of the car** itself.
#    - However, the crop’s x-values (582–635) fall **well within the left half of the image** (since 582 < 621).
#    - The right edge of the image is at **1242**, and the crop only reaches up to **635**, which is still **left of the center** (621).
#
# 3. **Car-Specific Perspective**
#    - If the car is centered in the image (a reasonable assumption for a rear-view photo), its body would span approximately symmetrically around the center (621).
#    - A crop located at **582–635** would lie **within the left portion of the car’s body**, not its right side.
#    - For the crop to represent the *right side of the car*, it would need to have an x-range closer to the right edge of the image (e.g., > 900), but this is not the case here.
#
# ### Conclusion
# The crop region **(582–635, 173–220)** is centered around the **left half of the image**, not the right side. While it does contain part of a black car (as described), it **does not satisfy the requirement** of being located on the **right side of the image** or the **right side of the car**.
#
# ✅ **Answer**: **No**, the crop is **not** "black cars in right" — it is positioned **left of the image center**, not on the right.
# [INFO] (2/4) Processing i101_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i101_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 94, y1: 171, x2: 176, y2: 207).
# [DEBUG] LLM response: no
# [INFO] (3/4) Processing i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=117, bbox={'x1': 200, 'y1': 171, 'x2': 249, 'y2': 200}, width=49, height=29, crop_path='crops/i117_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 200, y1: 171, x2: 249, y2: 200).
# [DEBUG] LLM response: no
# [INFO] (3/4) Processing i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# Crop_Img(frame_id=91, tracker_id=117, bbox={'x1': 200, 'y1': 171, 'x2': 249, 'y2': 200}, width=49, height=29, crop_path='crops/i117_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i117_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 200, y1: 171, x2: 249, y2: 200).
# [DEBUG] LLM response: no
# [INFO] (4/4) Processing i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=117, bbox={'x1': 200, 'y1': 171, 'x2': 249, 'y2': 200}, width=49, height=29, crop_path='crops/i117_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=174, bbox={'x1': 274, 'y1': 169, 'x2': 305, 'y2': 194}, width=31, height=25, crop_path='crops/i174_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 274, y1: 169, x2: 305, y2: 194).
# [DEBUG] LLM response: no
# [INFO] (4/4) Processing i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=2, bbox={'x1': 582, 'y1': 173, 'x2': 635, 'y2': 220}, width=53, height=47, crop_path='crops/i2_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=101, bbox={'x1': 94, 'y1': 171, 'x2': 176, 'y2': 207}, width=82, height=36, crop_path='crops/i101_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=117, bbox={'x1': 200, 'y1': 171, 'x2': 249, 'y2': 200}, width=49, height=29, crop_path='crops/i117_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# Crop_Img(frame_id=91, tracker_id=174, bbox={'x1': 274, 'y1': 169, 'x2': 305, 'y2': 194}, width=31, height=25, crop_path='crops/i174_f91.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i174_f91.jpg
# crop_details: the position of this crop in the original image is (x1: 274, y1: 169, x2: 305, y2: 194).
# [DEBUG] LLM response: no
# Frame 92, ID 2: x1=582, y1=173, w=53, h=46
# Frame 93, ID 2: x1=581, y1=172, w=55, h=48
# Frame 94, ID 2: x1=579, y1=172, w=57, h=49
# Frame 95, ID 2: x1=577, y1=170, w=60, h=53
# Frame 96, ID 2: x1=576, y1=170, w=61, h=53
# Frame 97, ID 2: x1=576, y1=171, w=60, h=52
# [DEBUG] LLM response: no
# Frame 92, ID 2: x1=582, y1=173, w=53, h=46
# Frame 93, ID 2: x1=581, y1=172, w=55, h=48
# Frame 94, ID 2: x1=579, y1=172, w=57, h=49
# Frame 95, ID 2: x1=577, y1=170, w=60, h=53
# Frame 96, ID 2: x1=576, y1=170, w=61, h=53
# Frame 97, ID 2: x1=576, y1=171, w=60, h=52
# Frame 98, ID 2: x1=576, y1=171, w=60, h=53
# Frame 99, ID 2: x1=574, y1=171, w=62, h=54
# Frame 100, ID 2: x1=574, y1=171, w=60, h=53
# Frame 101, ID 2: x1=573, y1=171, w=61, h=53
# Frame 102, ID 2: x1=572, y1=171, w=61, h=54
# Frame 103, ID 2: x1=570, y1=173, w=61, h=54
# Frame 104, ID 2: x1=568, y1=173, w=63, h=56
# Frame 98, ID 2: x1=576, y1=171, w=60, h=53
# Frame 99, ID 2: x1=574, y1=171, w=62, h=54
# Frame 100, ID 2: x1=574, y1=171, w=60, h=53
# Frame 101, ID 2: x1=573, y1=171, w=61, h=53
# Frame 102, ID 2: x1=572, y1=171, w=61, h=54
# Frame 103, ID 2: x1=570, y1=173, w=61, h=54
# Frame 104, ID 2: x1=568, y1=173, w=63, h=56
# Frame 105, ID 2: x1=568, y1=173, w=63, h=57
# Frame 106, ID 2: x1=566, y1=174, w=64, h=57
# Frame 107, ID 2: x1=566, y1=173, w=63, h=57
# Frame 108, ID 2: x1=565, y1=174, w=63, h=55
# Frame 109, ID 2: x1=564, y1=173, w=63, h=56
# Frame 110, ID 2: x1=563, y1=174, w=62, h=56
# Frame 111, ID 2: x1=561, y1=173, w=64, h=57
# Frame 105, ID 2: x1=568, y1=173, w=63, h=57
# Frame 106, ID 2: x1=566, y1=174, w=64, h=57
# Frame 107, ID 2: x1=566, y1=173, w=63, h=57
# Frame 108, ID 2: x1=565, y1=174, w=63, h=55
# Frame 109, ID 2: x1=564, y1=173, w=63, h=56
# Frame 110, ID 2: x1=563, y1=174, w=62, h=56
# Frame 111, ID 2: x1=561, y1=173, w=64, h=57
# Frame 112, ID 2: x1=560, y1=173, w=63, h=57
# Frame 113, ID 2: x1=557, y1=172, w=65, h=59
# Frame 114, ID 2: x1=556, y1=173, w=64, h=58
# Frame 115, ID 2: x1=555, y1=174, w=63, h=58
# Frame 116, ID 2: x1=553, y1=174, w=64, h=58
# Frame 117, ID 2: x1=551, y1=174, w=64, h=58
# Frame 118, ID 2: x1=550, y1=174, w=63, h=57
# Frame 119, ID 2: x1=549, y1=174, w=63, h=58
# Frame 120, ID 2: x1=548, y1=174, w=63, h=58
# [INFO] (1/1) Processing i2_f121.jpg
# Crop_Img(frame_id=121, tracker_id=2, bbox={'x1': 547, 'y1': 174, 'x2': 610, 'y2': 232}, width=63, height=58, crop_path='crops/i2_f121.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f121.jpg
# crop_details: the position of this crop in the original image is (x1: 547, y1: 174, x2: 610, y2: 232).
# Frame 112, ID 2: x1=560, y1=173, w=63, h=57
# Frame 113, ID 2: x1=557, y1=172, w=65, h=59
# Frame 114, ID 2: x1=556, y1=173, w=64, h=58
# Frame 115, ID 2: x1=555, y1=174, w=63, h=58
# Frame 116, ID 2: x1=553, y1=174, w=64, h=58
# Frame 117, ID 2: x1=551, y1=174, w=64, h=58
# Frame 118, ID 2: x1=550, y1=174, w=63, h=57
# Frame 119, ID 2: x1=549, y1=174, w=63, h=58
# Frame 120, ID 2: x1=548, y1=174, w=63, h=58
# [INFO] (1/1) Processing i2_f121.jpg
# Crop_Img(frame_id=121, tracker_id=2, bbox={'x1': 547, 'y1': 174, 'x2': 610, 'y2': 232}, width=63, height=58, crop_path='crops/i2_f121.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f121.jpg
# crop_details: the position of this crop in the original image is (x1: 547, y1: 174, x2: 610, y2: 232).
# [DEBUG] LLM response: no
# Frame 122, ID 2: x1=548, y1=174, w=62, h=57
# Frame 123, ID 2: x1=548, y1=173, w=62, h=57
# Frame 124, ID 2: x1=550, y1=173, w=61, h=57
# Frame 125, ID 2: x1=551, y1=174, w=63, h=58
# Frame 126, ID 2: x1=552, y1=174, w=63, h=58
# Frame 127, ID 2: x1=551, y1=174, w=65, h=59
# Frame 128, ID 2: x1=553, y1=176, w=63, h=58
# Frame 129, ID 2: x1=553, y1=176, w=64, h=58
# Frame 130, ID 2: x1=553, y1=177, w=65, h=59
# Frame 131, ID 2: x1=553, y1=177, w=65, h=59
# Frame 132, ID 2: x1=553, y1=177, w=65, h=59
# Frame 133, ID 2: x1=552, y1=177, w=65, h=59
# Frame 134, ID 2: x1=553, y1=177, w=64, h=59
# Frame 135, ID 2: x1=552, y1=177, w=65, h=59
# Frame 136, ID 2: x1=551, y1=177, w=65, h=59
# Frame 137, ID 2: x1=551, y1=177, w=65, h=59
# Frame 138, ID 2: x1=550, y1=177, w=66, h=59
# Frame 139, ID 2: x1=550, y1=177, w=66, h=59
# Frame 140, ID 2: x1=551, y1=177, w=64, h=59
# Frame 141, ID 2: x1=550, y1=177, w=66, h=59
# Frame 142, ID 2: x1=550, y1=178, w=64, h=59
# Frame 143, ID 2: x1=549, y1=178, w=64, h=58
# [DEBUG] LLM response: no
# Frame 122, ID 2: x1=548, y1=174, w=62, h=57
# Frame 123, ID 2: x1=548, y1=173, w=62, h=57
# Frame 124, ID 2: x1=550, y1=173, w=61, h=57
# Frame 125, ID 2: x1=551, y1=174, w=63, h=58
# Frame 126, ID 2: x1=552, y1=174, w=63, h=58
# Frame 127, ID 2: x1=551, y1=174, w=65, h=59
# Frame 128, ID 2: x1=553, y1=176, w=63, h=58
# Frame 129, ID 2: x1=553, y1=176, w=64, h=58
# Frame 130, ID 2: x1=553, y1=177, w=65, h=59
# Frame 131, ID 2: x1=553, y1=177, w=65, h=59
# Frame 132, ID 2: x1=553, y1=177, w=65, h=59
# Frame 133, ID 2: x1=552, y1=177, w=65, h=59
# Frame 134, ID 2: x1=553, y1=177, w=64, h=59
# Frame 135, ID 2: x1=552, y1=177, w=65, h=59
# Frame 136, ID 2: x1=551, y1=177, w=65, h=59
# Frame 137, ID 2: x1=551, y1=177, w=65, h=59
# Frame 138, ID 2: x1=550, y1=177, w=66, h=59
# Frame 139, ID 2: x1=550, y1=177, w=66, h=59
# Frame 140, ID 2: x1=551, y1=177, w=64, h=59
# Frame 141, ID 2: x1=550, y1=177, w=66, h=59
# Frame 142, ID 2: x1=550, y1=178, w=64, h=59
# Frame 143, ID 2: x1=549, y1=178, w=64, h=58
# Frame 144, ID 2: x1=549, y1=179, w=63, h=57
# Frame 145, ID 2: x1=548, y1=179, w=63, h=57
# Frame 146, ID 2: x1=548, y1=178, w=63, h=57
# Frame 147, ID 2: x1=548, y1=178, w=61, h=55
# Frame 148, ID 2: x1=547, y1=177, w=62, h=56
# Frame 149, ID 2: x1=546, y1=177, w=62, h=56
# Frame 150, ID 2: x1=545, y1=177, w=63, h=56
# [INFO] (1/1) Processing i2_f151.jpg
# Crop_Img(frame_id=151, tracker_id=2, bbox={'x1': 545, 'y1': 177, 'x2': 606, 'y2': 232}, width=61, height=55, crop_path='crops/i2_f151.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f151.jpg
# crop_details: the position of this crop in the original image is (x1: 545, y1: 177, x2: 606, y2: 232).
# Frame 144, ID 2: x1=549, y1=179, w=63, h=57
# Frame 145, ID 2: x1=548, y1=179, w=63, h=57
# Frame 146, ID 2: x1=548, y1=178, w=63, h=57
# Frame 147, ID 2: x1=548, y1=178, w=61, h=55
# Frame 148, ID 2: x1=547, y1=177, w=62, h=56
# Frame 149, ID 2: x1=546, y1=177, w=62, h=56
# Frame 150, ID 2: x1=545, y1=177, w=63, h=56
# [INFO] (1/1) Processing i2_f151.jpg
# Crop_Img(frame_id=151, tracker_id=2, bbox={'x1': 545, 'y1': 177, 'x2': 606, 'y2': 232}, width=61, height=55, crop_path='crops/i2_f151.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f151.jpg
# crop_details: the position of this crop in the original image is (x1: 545, y1: 177, x2: 606, y2: 232).
# [DEBUG] LLM response: no
# Frame 152, ID 2: x1=546, y1=178, w=59, h=53
# Frame 153, ID 2: x1=545, y1=177, w=60, h=55
# Frame 154, ID 2: x1=545, y1=177, w=61, h=55
# Frame 155, ID 2: x1=547, y1=178, w=60, h=54
# Frame 156, ID 2: x1=548, y1=178, w=59, h=53
# Frame 157, ID 2: x1=551, y1=178, w=54, h=48
# Frame 158, ID 2: x1=551, y1=178, w=56, h=50
# Frame 159, ID 2: x1=552, y1=178, w=56, h=50
# Frame 160, ID 2: x1=553, y1=178, w=57, h=51
# Frame 161, ID 2: x1=554, y1=178, w=57, h=50
# Frame 162, ID 2: x1=556, y1=178, w=55, h=49
# Frame 163, ID 2: x1=556, y1=179, w=56, h=49
# [DEBUG] LLM response: no
# Frame 152, ID 2: x1=546, y1=178, w=59, h=53
# Frame 153, ID 2: x1=545, y1=177, w=60, h=55
# Frame 154, ID 2: x1=545, y1=177, w=61, h=55
# Frame 155, ID 2: x1=547, y1=178, w=60, h=54
# Frame 156, ID 2: x1=548, y1=178, w=59, h=53
# Frame 157, ID 2: x1=551, y1=178, w=54, h=48
# Frame 158, ID 2: x1=551, y1=178, w=56, h=50
# Frame 159, ID 2: x1=552, y1=178, w=56, h=50
# Frame 160, ID 2: x1=553, y1=178, w=57, h=51
# Frame 161, ID 2: x1=554, y1=178, w=57, h=50
# Frame 162, ID 2: x1=556, y1=178, w=55, h=49
# Frame 163, ID 2: x1=556, y1=179, w=56, h=49
# Frame 164, ID 2: x1=555, y1=178, w=58, h=50
# Frame 165, ID 2: x1=555, y1=179, w=57, h=50
# Frame 166, ID 2: x1=554, y1=179, w=58, h=51
# Frame 167, ID 2: x1=554, y1=179, w=58, h=51
# Frame 168, ID 2: x1=556, y1=180, w=57, h=50
# Frame 169, ID 2: x1=558, y1=181, w=56, h=49
# Frame 170, ID 2: x1=558, y1=181, w=56, h=49
# Frame 171, ID 2: x1=559, y1=180, w=56, h=49
# Frame 172, ID 2: x1=559, y1=180, w=56, h=49
# Frame 173, ID 2: x1=561, y1=179, w=56, h=49
# Frame 164, ID 2: x1=555, y1=178, w=58, h=50
# Frame 165, ID 2: x1=555, y1=179, w=57, h=50
# Frame 166, ID 2: x1=554, y1=179, w=58, h=51
# Frame 167, ID 2: x1=554, y1=179, w=58, h=51
# Frame 168, ID 2: x1=556, y1=180, w=57, h=50
# Frame 169, ID 2: x1=558, y1=181, w=56, h=49
# Frame 170, ID 2: x1=558, y1=181, w=56, h=49
# Frame 171, ID 2: x1=559, y1=180, w=56, h=49
# Frame 172, ID 2: x1=559, y1=180, w=56, h=49
# Frame 173, ID 2: x1=561, y1=179, w=56, h=49
# Frame 174, ID 2: x1=561, y1=178, w=56, h=50
# Frame 175, ID 2: x1=563, y1=179, w=54, h=48
# Frame 176, ID 2: x1=564, y1=179, w=54, h=48
# Frame 177, ID 2: x1=565, y1=179, w=53, h=48
# Frame 178, ID 2: x1=566, y1=180, w=53, h=48
# Frame 179, ID 2: x1=566, y1=179, w=54, h=49
# Frame 174, ID 2: x1=561, y1=178, w=56, h=50
# Frame 175, ID 2: x1=563, y1=179, w=54, h=48
# Frame 176, ID 2: x1=564, y1=179, w=54, h=48
# Frame 177, ID 2: x1=565, y1=179, w=53, h=48
# Frame 178, ID 2: x1=566, y1=180, w=53, h=48
# Frame 179, ID 2: x1=566, y1=179, w=54, h=49
# Frame 180, ID 2: x1=567, y1=179, w=52, h=48
# [INFO] (1/3) Processing i2_f181.jpg
# Crop_Img(frame_id=181, tracker_id=2, bbox={'x1': 568, 'y1': 178, 'x2': 619, 'y2': 225}, width=51, height=47, crop_path='crops/i2_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f181.jpg
# crop_details: the position of this crop in the original image is (x1: 568, y1: 178, x2: 619, y2: 225).
# Frame 180, ID 2: x1=567, y1=179, w=52, h=48
# [INFO] (1/3) Processing i2_f181.jpg
# Crop_Img(frame_id=181, tracker_id=2, bbox={'x1': 568, 'y1': 178, 'x2': 619, 'y2': 225}, width=51, height=47, crop_path='crops/i2_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f181.jpg
# crop_details: the position of this crop in the original image is (x1: 568, y1: 178, x2: 619, y2: 225).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i291_f181.jpg
# Crop_Img(frame_id=181, tracker_id=2, bbox={'x1': 568, 'y1': 178, 'x2': 619, 'y2': 225}, width=51, height=47, crop_path='crops/i2_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i291_f181.jpg
# Crop_Img(frame_id=181, tracker_id=318, bbox={'x1': 499, 'y1': 181, 'x2': 537, 'y2': 211}, width=38, height=30, crop_path='crops/i318_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i291_f181.jpg
# Crop_Img(frame_id=181, tracker_id=291, bbox={'x1': 1095, 'y1': 200, 'x2': 1195, 'y2': 240}, width=100, height=40, crop_path='crops/i291_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i291_f181.jpg
# crop_details: the position of this crop in the original image is (x1: 1095, y1: 200, x2: 1195, y2: 240).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i291_f181.jpg
# Crop_Img(frame_id=181, tracker_id=2, bbox={'x1': 568, 'y1': 178, 'x2': 619, 'y2': 225}, width=51, height=47, crop_path='crops/i2_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i291_f181.jpg
# Crop_Img(frame_id=181, tracker_id=318, bbox={'x1': 499, 'y1': 181, 'x2': 537, 'y2': 211}, width=38, height=30, crop_path='crops/i318_f181.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i291_f181.jpg
# ...
#      - 632 is **11 pixels right of center** (632 - 621 = 11).
#      - This means the crop spans from **33 pixels left of center to 11 pixels right of center**, with the majority (588–610) being **left of the center**.
#    - **y = 178–218**:
#      - This lies **very close to the vertical center (187.5)**, meaning it is centered vertically in the image.
#
# 3. **Directional Interpretation**:
#    - In a typical rear-view camera perspective:
#      - **Same-direction (forward) lane** = **left side of the image** (relative to the center).
#      - **Counter-direction (opposite) lane** = **right side of the image** (relative to the center).
#    - The cropped area lies **predominantly on the left side of the image**, which corresponds to the **same direction** as the main car (not the counter-direction lane).
#
# 4. **Content Context**:
#    - The cropped region is **near the vertical center**, suggesting it is part of the **main vehicle** (e.g., rear lights, license plate, or other features), not a distant counter-direction vehicle.
#    - The small width (44 pixels) and height (40 pixels) further confirm it is a **localized section**, likely related to the main car rather than an external vehicle.
#
# ---
#
# ### Conclusion:
# The cropped image does **not** represent a car in the **counter direction**. Instead, it is located on the **same-direction side** of the image, likely depicting part of the main vehicle itself. Therefore, it **fails to meet the requirement**.
#
# **Answer: No** — the cropped image does **not** meet the requirement of showing a car in the counter direction.
# [INFO] (2/3) Processing i307_f211.jpg
# Crop_Img(frame_id=211, tracker_id=2, bbox={'x1': 588, 'y1': 178, 'x2': 632, 'y2': 218}, width=44, height=40, crop_path='crops/i2_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i307_f211.jpg
# Crop_Img(frame_id=211, tracker_id=307, bbox={'x1': 387, 'y1': 178, 'x2': 491, 'y2': 253}, width=104, height=75, crop_path='crops/i307_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i307_f211.jpg
# crop_details: the position of this crop in the original image is (x1: 387, y1: 178, x2: 491, y2: 253).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=2, bbox={'x1': 588, 'y1': 178, 'x2': 632, 'y2': 218}, width=44, height=40, crop_path='crops/i2_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=307, bbox={'x1': 387, 'y1': 178, 'x2': 491, 'y2': 253}, width=104, height=75, crop_path='crops/i307_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=438, bbox={'x1': 521, 'y1': 179, 'x2': 556, 'y2': 208}, width=35, height=29, crop_path='crops/i438_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# crop_details: the position of this crop in the original image is (x1: 521, y1: 179, x2: 556, y2: 208).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=2, bbox={'x1': 588, 'y1': 178, 'x2': 632, 'y2': 218}, width=44, height=40, crop_path='crops/i2_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=307, bbox={'x1': 387, 'y1': 178, 'x2': 491, 'y2': 253}, width=104, height=75, crop_path='crops/i307_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# Crop_Img(frame_id=211, tracker_id=438, bbox={'x1': 521, 'y1': 179, 'x2': 556, 'y2': 208}, width=35, height=29, crop_path='crops/i438_f211.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i438_f211.jpg
# crop_details: the position of this crop in the original image is (x1: 521, y1: 179, x2: 556, y2: 208).
# [DEBUG] LLM response: no
# Frame 212, ID 2: x1=588, y1=179, w=44, h=40
# Frame 213, ID 2: x1=589, y1=179, w=43, h=39
# Frame 214, ID 2: x1=589, y1=176, w=42, h=39
# Frame 215, ID 2: x1=588, y1=175, w=43, h=39
# Frame 216, ID 2: x1=588, y1=175, w=43, h=39
# Frame 217, ID 2: x1=588, y1=176, w=42, h=38
# Frame 218, ID 2: x1=589, y1=177, w=41, h=37
# [DEBUG] LLM response: no
# Frame 212, ID 2: x1=588, y1=179, w=44, h=40
# Frame 213, ID 2: x1=589, y1=179, w=43, h=39
# Frame 214, ID 2: x1=589, y1=176, w=42, h=39
# Frame 215, ID 2: x1=588, y1=175, w=43, h=39
# Frame 216, ID 2: x1=588, y1=175, w=43, h=39
# Frame 217, ID 2: x1=588, y1=176, w=42, h=38
# Frame 218, ID 2: x1=589, y1=177, w=41, h=37
# Frame 219, ID 2: x1=588, y1=179, w=42, h=37
# Frame 220, ID 2: x1=587, y1=180, w=44, h=39
# Frame 221, ID 2: x1=587, y1=181, w=44, h=39
# Frame 222, ID 2: x1=588, y1=182, w=43, h=39
# Frame 223, ID 2: x1=588, y1=181, w=43, h=38
# Frame 224, ID 2: x1=589, y1=180, w=43, h=38
# Frame 225, ID 2: x1=590, y1=180, w=42, h=37
# Frame 219, ID 2: x1=588, y1=179, w=42, h=37
# Frame 220, ID 2: x1=587, y1=180, w=44, h=39
# Frame 221, ID 2: x1=587, y1=181, w=44, h=39
# Frame 222, ID 2: x1=588, y1=182, w=43, h=39
# Frame 223, ID 2: x1=588, y1=181, w=43, h=38
# Frame 224, ID 2: x1=589, y1=180, w=43, h=38
# Frame 225, ID 2: x1=590, y1=180, w=42, h=37
# Frame 226, ID 2: x1=590, y1=179, w=42, h=38
# Frame 227, ID 2: x1=591, y1=178, w=43, h=37
# Frame 228, ID 2: x1=591, y1=177, w=42, h=36
# Frame 229, ID 2: x1=590, y1=177, w=42, h=36
# Frame 230, ID 2: x1=590, y1=178, w=41, h=35
# Frame 231, ID 2: x1=589, y1=177, w=42, h=36
# Frame 232, ID 2: x1=588, y1=178, w=41, h=35
# Frame 226, ID 2: x1=590, y1=179, w=42, h=38
# Frame 227, ID 2: x1=591, y1=178, w=43, h=37
# Frame 228, ID 2: x1=591, y1=177, w=42, h=36
# Frame 229, ID 2: x1=590, y1=177, w=42, h=36
# Frame 230, ID 2: x1=590, y1=178, w=41, h=35
# Frame 231, ID 2: x1=589, y1=177, w=42, h=36
# Frame 232, ID 2: x1=588, y1=178, w=41, h=35
# Frame 233, ID 2: x1=587, y1=178, w=41, h=36
# Frame 234, ID 2: x1=586, y1=179, w=41, h=35
# Frame 235, ID 2: x1=583, y1=176, w=43, h=37
# Frame 236, ID 2: x1=582, y1=175, w=44, h=38
# Frame 237, ID 2: x1=580, y1=174, w=45, h=39
# Frame 238, ID 2: x1=581, y1=175, w=44, h=38
# Frame 239, ID 2: x1=581, y1=174, w=44, h=39
# Frame 240, ID 2: x1=581, y1=174, w=43, h=39
# [INFO] (1/3) Processing i2_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 581, y1: 174, x2: 624, y2: 213).
# Frame 233, ID 2: x1=587, y1=178, w=41, h=36
# Frame 234, ID 2: x1=586, y1=179, w=41, h=35
# Frame 235, ID 2: x1=583, y1=176, w=43, h=37
# Frame 236, ID 2: x1=582, y1=175, w=44, h=38
# Frame 237, ID 2: x1=580, y1=174, w=45, h=39
# Frame 238, ID 2: x1=581, y1=175, w=44, h=38
# Frame 239, ID 2: x1=581, y1=174, w=44, h=39
# Frame 240, ID 2: x1=581, y1=174, w=43, h=39
# [INFO] (1/3) Processing i2_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 581, y1: 174, x2: 624, y2: 213).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i456_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i456_f241.jpg
# Crop_Img(frame_id=241, tracker_id=456, bbox={'x1': 146, 'y1': 173, 'x2': 219, 'y2': 216}, width=73, height=43, crop_path='crops/i456_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i456_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 146, y1: 173, x2: 219, y2: 216).
# [DEBUG] LLM response: no
# [INFO] (2/3) Processing i456_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i456_f241.jpg
# Crop_Img(frame_id=241, tracker_id=456, bbox={'x1': 146, 'y1': 173, 'x2': 219, 'y2': 216}, width=73, height=43, crop_path='crops/i456_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i456_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 146, y1: 173, x2: 219, y2: 216).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=456, bbox={'x1': 146, 'y1': 173, 'x2': 219, 'y2': 216}, width=73, height=43, crop_path='crops/i456_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=457, bbox={'x1': 357, 'y1': 179, 'x2': 477, 'y2': 267}, width=120, height=88, crop_path='crops/i457_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 357, y1: 179, x2: 477, y2: 267).
# [DEBUG] LLM response: no
# [INFO] (3/3) Processing i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=2, bbox={'x1': 581, 'y1': 174, 'x2': 624, 'y2': 213}, width=43, height=39, crop_path='crops/i2_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=456, bbox={'x1': 146, 'y1': 173, 'x2': 219, 'y2': 216}, width=73, height=43, crop_path='crops/i456_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# Crop_Img(frame_id=241, tracker_id=457, bbox={'x1': 357, 'y1': 179, 'x2': 477, 'y2': 267}, width=120, height=88, crop_path='crops/i457_f241.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i457_f241.jpg
# crop_details: the position of this crop in the original image is (x1: 357, y1: 179, x2: 477, y2: 267).
# [DEBUG] LLM response: no
# Frame 242, ID 2: x1=581, y1=175, w=43, h=38
# Frame 243, ID 2: x1=581, y1=175, w=43, h=38
# Frame 244, ID 2: x1=581, y1=175, w=42, h=39
# Frame 245, ID 2: x1=582, y1=175, w=41, h=38
# Frame 246, ID 2: x1=583, y1=175, w=40, h=37
# Frame 247, ID 2: x1=583, y1=176, w=39, h=36
# Frame 248, ID 2: x1=583, y1=176, w=39, h=36
# [DEBUG] LLM response: no
# Frame 242, ID 2: x1=581, y1=175, w=43, h=38
# Frame 243, ID 2: x1=581, y1=175, w=43, h=38
# Frame 244, ID 2: x1=581, y1=175, w=42, h=39
# Frame 245, ID 2: x1=582, y1=175, w=41, h=38
# Frame 246, ID 2: x1=583, y1=175, w=40, h=37
# Frame 247, ID 2: x1=583, y1=176, w=39, h=36
# Frame 248, ID 2: x1=583, y1=176, w=39, h=36
# Frame 249, ID 2: x1=583, y1=178, w=38, h=36
# Frame 250, ID 2: x1=584, y1=180, w=37, h=34
# Frame 251, ID 2: x1=584, y1=180, w=37, h=35
# Frame 252, ID 2: x1=583, y1=179, w=38, h=36
# Frame 253, ID 2: x1=582, y1=178, w=39, h=36
# Frame 254, ID 2: x1=583, y1=178, w=38, h=36
# Frame 255, ID 2: x1=583, y1=178, w=38, h=35
# Frame 249, ID 2: x1=583, y1=178, w=38, h=36
# Frame 250, ID 2: x1=584, y1=180, w=37, h=34
# Frame 251, ID 2: x1=584, y1=180, w=37, h=35
# Frame 252, ID 2: x1=583, y1=179, w=38, h=36
# Frame 253, ID 2: x1=582, y1=178, w=39, h=36
# Frame 254, ID 2: x1=583, y1=178, w=38, h=36
# Frame 255, ID 2: x1=583, y1=178, w=38, h=35
# Frame 256, ID 2: x1=582, y1=178, w=39, h=36
# Frame 257, ID 2: x1=583, y1=178, w=38, h=36
# Frame 258, ID 2: x1=583, y1=178, w=38, h=36
# Frame 259, ID 2: x1=583, y1=174, w=38, h=36
# Frame 260, ID 2: x1=584, y1=171, w=38, h=36
# Frame 261, ID 2: x1=584, y1=171, w=38, h=36
# Frame 262, ID 2: x1=585, y1=174, w=37, h=35
# Frame 256, ID 2: x1=582, y1=178, w=39, h=36
# Frame 257, ID 2: x1=583, y1=178, w=38, h=36
# Frame 258, ID 2: x1=583, y1=178, w=38, h=36
# Frame 259, ID 2: x1=583, y1=174, w=38, h=36
# Frame 260, ID 2: x1=584, y1=171, w=38, h=36
# Frame 261, ID 2: x1=584, y1=171, w=38, h=36
# Frame 262, ID 2: x1=585, y1=174, w=37, h=35
# Frame 263, ID 2: x1=585, y1=174, w=37, h=35
# Frame 264, ID 2: x1=584, y1=171, w=39, h=37
# Frame 265, ID 2: x1=584, y1=171, w=39, h=36
# Frame 266, ID 2: x1=585, y1=170, w=37, h=36
# Frame 267, ID 2: x1=584, y1=170, w=38, h=37
# Frame 263, ID 2: x1=585, y1=174, w=37, h=35
# Frame 264, ID 2: x1=584, y1=171, w=39, h=37
# Frame 265, ID 2: x1=584, y1=171, w=39, h=36
# Frame 266, ID 2: x1=585, y1=170, w=37, h=36
# Frame 267, ID 2: x1=584, y1=170, w=38, h=37
# Frame 268, ID 2: x1=583, y1=171, w=39, h=36
# Frame 269, ID 2: x1=583, y1=171, w=39, h=37
# Frame 270, ID 2: x1=583, y1=171, w=39, h=37
# [INFO] (1/6) Processing i2_f271.jpg
# Crop_Img(frame_id=271, tracker_id=2, bbox={'x1': 583, 'y1': 171, 'x2': 622, 'y2': 208}, width=39, height=37, crop_path='crops/i2_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f271.jpg
# crop_details: the position of this crop in the original image is (x1: 583, y1: 171, x2: 622, y2: 208).
# Frame 268, ID 2: x1=583, y1=171, w=39, h=36
# Frame 269, ID 2: x1=583, y1=171, w=39, h=37
# Frame 270, ID 2: x1=583, y1=171, w=39, h=37
# [INFO] (1/6) Processing i2_f271.jpg
# Crop_Img(frame_id=271, tracker_id=2, bbox={'x1': 583, 'y1': 171, 'x2': 622, 'y2': 208}, width=39, height=37, crop_path='crops/i2_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i2_f271.jpg
# crop_details: the position of this crop in the original image is (x1: 583, y1: 171, x2: 622, y2: 208).
# [DEBUG] LLM response: no
# [INFO] (2/6) Processing i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=2, bbox={'x1': 583, 'y1': 171, 'x2': 622, 'y2': 208}, width=39, height=37, crop_path='crops/i2_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=502, bbox={'x1': 423, 'y1': 178, 'x2': 501, 'y2': 236}, width=78, height=58, crop_path='crops/i502_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=508, bbox={'x1': 510, 'y1': 172, 'x2': 552, 'y2': 204}, width=42, height=32, crop_path='crops/i508_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=516, bbox={'x1': 553, 'y1': 172, 'x2': 572, 'y2': 192}, width=19, height=20, crop_path='crops/i516_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=517, bbox={'x1': 283, 'y1': 177, 'x2': 318, 'y2': 200}, width=35, height=23, crop_path='crops/i517_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=486, bbox={'x1': 81, 'y1': 180, 'x2': 157, 'y2': 218}, width=76, height=38, crop_path='crops/i486_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# crop_details: the position of this crop in the original image is (x1: 81, y1: 180, x2: 157, y2: 218).
# [DEBUG] LLM response: no
# [INFO] (2/6) Processing i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=2, bbox={'x1': 583, 'y1': 171, 'x2': 622, 'y2': 208}, width=39, height=37, crop_path='crops/i2_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=502, bbox={'x1': 423, 'y1': 178, 'x2': 501, 'y2': 236}, width=78, height=58, crop_path='crops/i502_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=508, bbox={'x1': 510, 'y1': 172, 'x2': 552, 'y2': 204}, width=42, height=32, crop_path='crops/i508_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=516, bbox={'x1': 553, 'y1': 172, 'x2': 572, 'y2': 192}, width=19, height=20, crop_path='crops/i516_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=517, bbox={'x1': 283, 'y1': 177, 'x2': 318, 'y2': 200}, width=35, height=23, crop_path='crops/i517_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# Crop_Img(frame_id=271, tracker_id=486, bbox={'x1': 81, 'y1': 180, 'x2': 157, 'y2': 218}, width=76, height=38, crop_path='crops/i486_f271.jpg')
# file_path: /home/seanachan/ByteTrack_ultralytics/crops/i486_f271.jpg
# crop_details: the position of this crop in the original image is (x1: 81, y1: 180, x2: 157, y2: 218).

# %% [markdown]
# ## Create output directory
#
# ### Subtask:
# Create a directory to store the annotated frames and the final video.

# %% [markdown]
# **Reasoning**:
# To create the output directory as instructed, I will import the `os` module, define the directory name, and then use `os.makedirs` to create it.

# %%
import os

output_dir = os.path.join(HOME, "tracking_output")
os.makedirs(output_dir, exist_ok=True)
print(f"Output directory created at: {output_dir}")

# %% [markdown]
# **Reasoning**:
# Now that the output directory is created, I need to iterate through the `results` object obtained from `model.track()`, save each annotated frame as an image file in the newly created `output_dir`.

# %%
for i, result in enumerate(results):
    # Save the annotated image to the output directory
    image_path = os.path.join(output_dir, f"frame_{i:04d}.jpg") # Using JPG for smaller size
    result.save(filename=image_path)
    if i % 50 == 0:
        print(f"Saved frame {i} to {image_path}")
print(f"All annotated frames saved to {output_dir}")

# %% [markdown]
# **Reasoning**:
# Now that all annotated frames are saved, I will use OpenCV to compile these frames into a video file. I'll define video parameters like codec, frame rate, and output path, then iterate through the saved images, read them, and write them to the video.

# %%
import cv2
import glob

# Get a list of all saved image files, sorted by name to ensure correct frame order
image_files = sorted(glob.glob(os.path.join(output_dir, "frame_*.jpg")))

if not image_files:
    print("No frames found to create video.")
else:
    # Read the first image to get dimensions
    first_frame = cv2.imread(image_files[0])
    height, width, layers = first_frame.shape
    size = (width, height)

    # Define the codec and create VideoWriter object
    video_name = os.path.join(output_dir, 'tracking_output.mp4')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # You can choose other codecs like 'MJPG', 'XVID', 'mp4v'
    fps = 10 # Frames per second
    out = cv2.VideoWriter(video_name, fourcc, fps, size)

    # Write each frame to the video file
    for img_file in image_files:
        img = cv2.imread(img_file)
        out.write(img)

    out.release()
    print(f"Video created successfully at: {video_name}")

# %%
# Run draw_boxes.py from the notebook cell
import os, subprocess, shlex

images_dir = os.path.join(KITTI_PATH, "0005")
cmd = f'python draw_boxes.py --gt_file predict.txt --images_dir "{images_dir}" --output_dir tracking_viz'

print("Running:", cmd)
proc = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
print(proc.stdout)
if proc.returncode != 0:
    print("Return code:", proc.returncode)
    print(proc.stderr)

# %% [markdown]
# # Looping through all files in refer-kitti
